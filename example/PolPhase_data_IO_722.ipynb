# %% [markdown]
# # Polscope phase large data processer

# %% [markdown]
# - 7/22/19 data. 5 slices. ~60 viable timepoints, total of 3 hours. 5 positions.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import hsv_to_rgb
from numpy.fft import fft2, ifft2, fftshift, ifftshift

import sys
import glob
from PIL import Image
from skimage import io
import pims
import pickle
import os
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual

import waveorder as wo

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
plt.style.use(['dark_background']) # Plotting option for dark background
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Reading files using optimized method (according to IO Speeds notebook from czbiohub/virusLifecycle).
def optimizedReading(img_paths):
    """This function takes in a list of image paths i.e. ["../path1, ../path2"] 
    and reads each image into a numpy array."""
    
    length = len(img_paths)
    empty = np.empty((length, 2048, 2048), dtype = 'uint16')
    
    for num, img in zip(np.arange(length), img_paths):
        empty[num,:,:] = io.imread(img)
    
    return empty

# %%
#Adapted from Li-Hao's visual.py
def hyper_stack_viewer(image_stack, slices, time, size=(10,10), colormap='gray', phase = False):
    
    '''
    Visualize xyzt stacks.
    image_stack: Stack of images in xyzt order 
    slices: the number of slices
    time: the number of timepoints
    Example data: 
        [imgz0t0, imgz1t0, img z2t0, imgz0t1, imgz1t1, img z2t1]
        slices = 3
        time = 2
    '''
    if phase == True:
        max_val = 2.5
        min_val = -1.5
    else:
        max_val = np.percentile(image_stack, 99.99)
        min_val = np.min(image_stack)

    def interact_plot_4D(z, t):    
        plt.figure(figsize=size)
        plt.imshow(image_stack[t*slices + z],cmap=colormap, vmin=min_val, vmax=max_val)
        plt.colorbar()
    
    return interact(interact_plot_4D, z=widgets.IntSlider(value=0, min=0, max=slices-1, step=1),
                    t=widgets.IntSlider(value=0, min=0, max=time, step=1))

# %%
n_media       = 1.512               # refractive index of the immersed media for objective (oil: 1.512, water: 1.33, air: 1)
lambda_illu   = 0.532               # illumination wavelength (um)
mag           = 63                  # magnification of the microscope                      
NA_obj        = 1.47                # detection NA of the objective
NA_illu       = 0.4                 # illumination NA of the condenser
N_defocus     = 5                   # number of defocus images
N_time        = 60
N_channel     = 5                   # number of Polscope channels
z_step        = 1               # z_step of the stack
z_defocus     = -(np.r_[:N_defocus]-N_defocus//2)*z_step
chi           = 0.03*2*np.pi        # swing of the LC
ps            = 6.45/mag            # effective pixel size at the sample plane (cam pix/mag in um)
cali          = True                # correction for S1/S2 Polscope reconstruction (does not affect phase)
bg_option     = 'local_fit'         # background correction method for Polscope recon (does not affect phase)
data_path     = '/mnt/comp_micro/Hummingbird/RawData/Interns/2019_07_22/U2OS untreated_1/' # data path
bg_path       = '/mnt/comp_micro/Hummingbird/RawData/Interns/2019_07_22/Empty_Background/Pos0/'# background data path
output_path   = '/mnt/comp_micro/Projects/nucleolus/labelfree_segmentation/phase_recon/7_22_19_6well/'# output image path

# %%
z_defocus
# Out:
# array([ 0.5 ,  0.25,  0.  , -0.25, -0.5 ])

# %%
data_paths = sorted(glob.glob(data_path + "*Pos*"))

# %%
data_paths
# Out:
# ['/mnt/comp_micro/Hummingbird/RawData/Interns/2019_07_22/U2OS untreated_1/Pos0',
#  '/mnt/comp_micro/Hummingbird/RawData/Interns/2019_07_22/U2OS untreated_1/Pos1',
#  '/mnt/comp_micro/Hummingbird/RawData/Interns/2019_07_22/U2OS untreated_1/Pos2',
#  '/mnt/comp_micro/Hummingbird/RawData/Interns/2019_07_22/U2OS untreated_1/Pos3',
#  '/mnt/comp_micro/Hummingbird/RawData/Interns/2019_07_22/U2OS untreated_1/Pos4']

# %%
output_paths = [output_path + "Pos" + str(i) for i in range(len(data_paths))]

# %%
output_paths
# Out:
# ['/mnt/comp_micro/Projects/nucleolus/labelfree_segmentation/phase_recon/7_22_19_6well/Pos0',
#  '/mnt/comp_micro/Projects/nucleolus/labelfree_segmentation/phase_recon/7_22_19_6well/Pos1',
#  '/mnt/comp_micro/Projects/nucleolus/labelfree_segmentation/phase_recon/7_22_19_6well/Pos2',
#  '/mnt/comp_micro/Projects/nucleolus/labelfree_segmentation/phase_recon/7_22_19_6well/Pos3',
#  '/mnt/comp_micro/Projects/nucleolus/labelfree_segmentation/phase_recon/7_22_19_6well/Pos4']

# %%
# solver option

deconv = 'TV'         # deconvolution method

if deconv == 'Tikhonov':
    reg_u = 1e-1      # absorption regularizer (larger the smoother but less contrast)
    reg_p = 1e-3      # phase regularizer
    
elif deconv == 'TV':
    lambda_u = 1e-2   # absorption regularizer
    lambda_p = 1e-2   # phase regularizer
    rho = 1.5         # rho coefficient of ADMM algorithm (the larger the less noisy and contrast)
    itr = 10          # number of ADMM iteration (10 is usually good)
    verbose = False   # report of the iteration number or not

# %%
# Plot setting

max_phase = 2.5                      # maximum phase value to display
min_phase = -1.5                     # minimum phase value to display

max_ret   = 2e-3/lambda_illu*2*np.pi # maximum retardance value
all_z     = False                    # plot all z birefringence or not
z_layer   = 2                        # focal layer to plot if only plot single layer
recon_birefringence = False           # Reconstruct birefringence?
recon_phase = True                  # Reconstruct phase?
test = True                          # Tuning lambda
lambdas = [1e-1,1e-2,1e-3]

# %%
filedir = data_path + '*0[0-5][0-9]_state*.tif'
filedir_bg = bg_path + '*Acquired*.tif'
files = sorted(glob.glob(filedir), key=wo.numericalSort)
files_bg = sorted(glob.glob(filedir_bg), key=wo.numericalSort)

# %%
#N_z*N_channels should match the number of files
assert len(files) == N_defocus*N_channel*N_time
# Only 5 background images for Polstates 0-4 are needed.
assert len(files_bg) == 5
# Background images should not be cropped.
#assert all(io.imread(files_bg[i]).shape == (2048,2048) for i in range(5))

# %%
#Visualizing one channel just to find the right z-defocus
stack = optimizedReading(files[0:5])

# %%
hyper_stack_viewer(stack, 5, 0, size = (20,20))
# Out:
# interactive(children=(IntSlider(value=0, description='z', max=4), IntSlider(value=0, description='t', max=0), …
# <function __main__.hyper_stack_viewer.<locals>.interact_plot_4D(z, t)>

# %%
#select a FOV for processing

Ns = 2048
Ms = 2048
n_start = [0, 0]
# Ns = 750
# Ms = 750
# n_start = [250, 0] # grating target


plt.figure(figsize=(10,10))
plt.imshow(io.imread(files[2]).astype('float64')[n_start[0]:n_start[0]+Ns, n_start[1]:n_start[1]+Ms], cmap = 'gray')

# %%
# %time
setup = wo.waveorder_microscopy((Ns,Ms), lambda_illu, ps, NA_obj, NA_illu, z_defocus, chi,\
                                n_media=n_media, cali=cali, bg_option=bg_option)
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 10.5 µs

# %%
os.system('mkdir '+output_path)
os.system('mkdir '+output_path+'test')
os.system('mkdir '+output_path+'phase')
os.system('mkdir '+output_path+'birefringence')
# Out:
# 0

# %%
output_path
# Out:
# '/mnt/comp_micro/Projects/nucleolus/labelfree_segmentation/phase_recon/'

# %%
def waveorder_test(raw_imgs, bg_imgs, forward, lambdas):
    """Helper function to wrap PolPhase_data_IO notebooks."""
    
    Nimg = N_defocus*N_channel
    N_time = 1

    # Load background images
    Nbg = len(bg_imgs)
    I_bg_pre = []
    for i in range(0, Nbg):
        Itemp = io.imread(bg_imgs[i]).astype('float64')[n_start[0]:n_start[0]+Ns, n_start[1]:n_start[1]+Ms] + 1
        I_bg_pre.append(Itemp)
        sys.stdout.write("\r" + "Loaded Background " + str(i))
        sys.stdout.flush()

    I_bg_pre = np.array(I_bg_pre)
    I_bg = np.zeros_like(I_bg_pre)
    I_bg = wo.intensity_mapping(I_bg_pre)

    for m in range(N_time):
        # Load Polscope images
        I_meas_pre =[]

        for i in range(0, Nimg):
            Itemp = io.imread(raw_imgs[m*Nimg+i]).astype('float64')[n_start[0]:n_start[0]+Ns, n_start[1]:n_start[1]+Ms]
            I_meas_pre.append(Itemp)
            sys.stdout.write("\r" + "Loaded Polscope image " + str(i))
            sys.stdout.flush()

        I_meas_pre = np.array(I_meas_pre)
        I_meas_pre = np.transpose(I_meas_pre.reshape((N_channel, N_defocus, Ns, Ms)), (0,2,3,1))

        # intensity mapping to match the theory
        I_meas = np.zeros_like(I_meas_pre)
        for i in range(N_defocus):
            I_meas[:,:,:,i] = wo.intensity_mapping(I_meas_pre[:,:,:,i])
            sys.stdout.write("\r" + "Intensity mapping " + str(i))
            sys.stdout.flush()


        # Stokes vector recon with bg correction
        S_image_recon = forward.Stokes_recon(I_meas)
        S_bg_recon = forward.Stokes_recon(I_bg)
        S_image_tm = forward.Stokes_transform(S_image_recon)
        S_bg_tm = forward.Stokes_transform(S_bg_recon)
        S_image_tm = forward.Polscope_bg_correction(S_image_tm, S_bg_tm)    
        Recon_para = forward.Polarization_recon(S_image_tm)

        # Take out S0 for phase reconstruction
        S0_stack = S_image_tm[0].copy()

        phase_imgs = []
        for mu in lambdas:
            print("Test " + str(mu))
            if deconv == 'Tikhonov':
                mu_sample, phi_sample = forward.Phase_recon(S0_stack, method='Tikhonov', reg_u = mu, reg_p = reg_p)

            elif deconv == 'TV':
                mu_sample, phi_sample = forward.Phase_recon(S0_stack, method='TV', lambda_u = mu, lambda_p = lambda_p, \
                                                      itr = itr, rho=rho, verbose = verbose)
            #file_name_phase = output_path+'phase/'+raw_imgs[m].split('state')[0].rsplit('/')[-1]+str(mu)+'phase.tiff'
            phase_imgs.append(phi_sample)

        phase_imgs = np.array(phase_imgs)
    return phase_imgs

# %%
test = waveorder_test(files, files_bg, setup,lambdas)
# Out:
# Intensity mapping 4ge 24Test 0.1
# Test 0.01
# Test 0.001

# %%
hyper_stack_viewer(test,3,1)
# Out:
# interactive(children=(IntSlider(value=0, description='z', max=2), IntSlider(value=0, description='t', max=1), …
# <function __main__.hyper_stack_viewer.<locals>.interact_plot_4D(z, t)>

# %%
#After tuning for lambda, reconstruct batch.
Nimg = N_defocus*N_channel
N_time = len(files)//Nimg

# Load background images
Nbg = len(files_bg)
I_bg_pre = []
for i in range(0, Nbg):
    Itemp = io.imread(files_bg[i]).astype('float64')[n_start[0]:n_start[0]+Ns, n_start[1]:n_start[1]+Ms] + 1
    I_bg_pre.append(Itemp)
    sys.stdout.write("\r" + "Loaded Background " + str(i))
    sys.stdout.flush()
    
I_bg_pre = np.array(I_bg_pre)

I_bg = np.zeros_like(I_bg_pre)
I_bg = wo.intensity_mapping(I_bg_pre)

for m in range(N_time):
    
    # Load Polscope images
    I_meas_pre =[]

    for i in range(0, Nimg):
        Itemp = io.imread(files[m*Nimg+i]).astype('float64')[n_start[0]:n_start[0]+Ns, n_start[1]:n_start[1]+Ms]
        I_meas_pre.append(Itemp)
        sys.stdout.write("\r" + "Loaded Polscope image " + str(i))
        sys.stdout.flush()
        
    I_meas_pre = np.array(I_meas_pre)
    I_meas_pre = np.transpose(I_meas_pre.reshape((N_channel, N_defocus, Ns, Ms)), (0,2,3,1))
    
    # intensity mapping to match the theory
    I_meas = np.zeros_like(I_meas_pre)
    for i in range(N_defocus):
        I_meas[:,:,:,i] = wo.intensity_mapping(I_meas_pre[:,:,:,i])
        sys.stdout.write("\r" + "Intensity mapping " + str(i))
        sys.stdout.flush()
    
    
    # Stokes vector recon with bg correction
    S_image_recon = setup.Stokes_recon(I_meas)
    S_bg_recon = setup.Stokes_recon(I_bg)
    S_image_tm = setup.Stokes_transform(S_image_recon)
    S_bg_tm = setup.Stokes_transform(S_bg_recon)
    S_image_tm = setup.Polscope_bg_correction(S_image_tm, S_bg_tm)    
    Recon_para = setup.Polarization_recon(S_image_tm)
    
    # Take out S0 for phase reconstruction
    S0_stack = S_image_tm[0].copy()

    # Phase reconstruction. Trying different regularizers.
    if recon_phase == True:
        
        if deconv == 'Tikhonov':
            mu_sample, phi_sample = setup.Phase_recon(S0_stack, method='Tikhonov', reg_u = reg_u, reg_p = reg_p)

        elif deconv == 'TV':
            mu_sample, phi_sample = setup.Phase_recon(S0_stack, method='TV', lambda_u = lambda_u, lambda_p = lambda_p, \
                                                      itr = itr, rho=rho, verbose = verbose)

        # figure plotting as tiff files
        file_name_phase = output_path+'phase/'+files[m*Nimg].split('state')[0].rsplit('/')[-1]+'phase.tiff'
        plt.imsave(file_name_phase, phi_sample, format="tiff", cmap=plt.cm.gray, vmin=min_phase, vmax=max_phase)
    
    if all_z == True:
        for i in range(N_defocus):

            bi_hsv = np.transpose(np.array([Recon_para[1,:,:,i]/np.pi, \
                                               np.ones((Ns,Ms)), \
                                               np.clip(Recon_para[0,:,:,i]/max_ret,0,1)]), (1,2,0))
            bi_rgb = hsv_to_rgb(bi_hsv.copy())


            file_name_bire = output_path+'birefringence/'+files[m*Nimg+i].split('state0')[0].split('/')[1]\
                            +files[m*Nimg+i].split('state0')[1].split('.')[0]+'_birefringence.tiff'
            plt.imsave(file_name_bire, bi_rgb, format="tiff")
    
    elif recon_birefringence == True:
#             bi_hsv = np.transpose(np.array([Recon_para[1,:,:,z_layer]/np.pi, \
#                                                np.ones((Ns,Ms)), \
#                                                np.clip(Recon_para[0,:,:,z_layer]/max_ret,0,1)]), (1,2,0))
            norm_phase = np.clip(phi_sample, min_phase, max_phase)-min_phase
            norm_phase /= np.max(norm_phase)
            bi_hsv = np.transpose(np.array([Recon_para[1,:,:,z_layer]/np.pi, \
                                               np.clip(Recon_para[0,:,:,z_layer]/max_ret,0,1), \
                                               norm_phase]), (1,2,0))
            bi_rgb_temp = hsv_to_rgb(bi_hsv.copy())
            bi_rgb = np.zeros_like(bi_rgb_temp)
            bi_rgb[:,:,0] = bi_rgb_temp[:,:,2]
            bi_rgb[:,:,1] = bi_rgb_temp[:,:,1]
            bi_rgb[:,:,2] = bi_rgb_temp[:,:,0]


            file_name_bire = output_path+'birefringence/'+files[m*Nimg+z_layer].split('state0')[0].rsplit('/')[-1]\
                            +files[m*Nimg+z_layer].split('state0')[1].split('.')[0]+'_birefringence.tiff'
            plt.imsave(file_name_bire, bi_rgb, format="tiff")

    print('Number of image stacks processed (%d / %d)'%(m+1,N_time))
# Out:
# Loaded Background 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-107-493c3a5bb6b8> in <module>
#      14 I_bg_pre = np.array(I_bg_pre)
#      15
# ---> 16 I_bg = np.zeros_like(I_bg_pre)
#      17 I_bg = wo.intensity_mapping(I_bg_pre)
#      18
#
# /mnt/data_lg/andrew/miniconda3/lib/python3.6/site-packages/numpy/core/numeric.py in zeros_like(a, dtype, order, subok)
#     169     # needed instead of a 0 to get same result as zeros for for string dtypes
#     170     z = zeros(1, dtype=res.dtype)
# --> 171     multiarray.copyto(res, z, casting='unsafe')
#     172     return res
#     173
#
# KeyboardInterrupt:
