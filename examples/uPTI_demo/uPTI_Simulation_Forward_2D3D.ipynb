# %% [markdown]
# # Forward simulation of uniaxial permittivity tensor imaging (uPTI)
# This simulation is based on the uPTI paper [here](https://www.biorxiv.org/content/10.1101/2020.12.15.422951v1): <br>
# ``` L.-H. Yeh, I. E. Ivanov, B. B. Chhun, S.-M. Guo, E. Hashemi, J. R. Byrum, J. A. Pérez-Bermejo, H. Wang, Y. Yu, P. G. Kazansky, B. R. Conklin, M. H. Han, and S. B. Mehta, "uPTI: uniaxial permittivity tensor imaging of intrinsic density and anisotropy," bioRxiv 2020.12.15.422951 (2020).```

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.fft import fft, ifft, fft2, ifft2, fftshift, ifftshift, fftn, ifftn

import pickle
import waveorder as wo
import time



# %matplotlib inline

# %% [markdown]
# ## Initialization - imaging system and sample

# %% [markdown]
# ### Assumptions

# %% [markdown]
# *  In our simulations, the specimen is always assumed to be 3D in order to model volumetric scattering.
# * A 2D specimen, i.e., a specimen thinner than the depth of focus of the microscope, is simulated by setting a single layer of the volume to sample properties.
# For a 2D specimen, all layers other than sample layer are assumed to have the isotropic permittivity of the surrounding medium.
# * This forward simulation generates 3D intensity stacks acquired with 9 patterns of asymmetric illumination and 4 polarization states for both a 2D thin specimen or a 3D specimen.
# * 3D reconstruction notebook can be used to reconstruct the 3D uPT of the 2D or 3D specimen given their intensity stacks.
# The 3D reconstruction of 2D specimen will report isotropic permittivity of medium outside of the depth of focus of the microscope.
# * 2D reconstruction notebook computes 2D uPT from a slice of the intensity stacks and it only works for the 2D thin specimen.

# %% [markdown]
# ### Parameters of sample

# %%
sample_type = '2D'               # 2D or 3D
N           = 200                 # number of pixel in y dimension
M           = 200                 # number of pixel in x dimension
L           = 100                 # number of layers in z dimension
z_layer     = 50                  # default z-slice to display in XY views.
y_layer     = 100                 # default y-slice to display in XZ views.

# %% [markdown]
# ### Parameters of imaging system

# %%
n_media     = 1.518               # refractive index in the media
mag         = 63                  # magnification
ps          = 6/mag               # effective pixel size
psz         = 0.125/2             # axial pixel size
lambda_illu = 0.532               # wavelength
NA_obj      = 1.47                # objective NA
NA_illu     = 1.4                 # illumination NA
chi         = 0.25*2*np.pi        # swing of the microscope
z_defocus = (np.r_[:L]-L//2)*psz  # defocus position
use_gpu     = True                # option to use gpu
gpu_id      = 0                   # gpu to be used

# %% [markdown]
# ### Sample pattern

# %%
if sample_type == '3D':
    # 3D spoke pattern whose spokes are inclined 60 degrees relative to the z-axis. The principal retardance varies with depth and 3D orientation of permittivity tensor is aligned with the structural orientation of the spoke.
    blur_size = 1*ps
    target, azimuth, inclination = wo.genStarTarget_3D((N,M,L), ps, psz, blur_size, inc_upper_bound=np.pi/8, inc_range=np.pi/64)
    inclination = np.round(inclination/np.pi*8)/8*np.pi
    azimuth   = np.round(azimuth/np.pi/2*16)/16*np.pi*2
elif sample_type == '2D':
    ## 2D spoke pattern, azimuth aligned with spokes, and the inclination set to 60 degrees ##
    target, azimuth, _ = wo.genStarTarget(N,M, blur_px=1*ps, margin=60)
    inclination = np.ones_like(target)*np.pi/3
    azimuth   = azimuth%(np.pi*2)
    azimuth   = np.round(azimuth/np.pi/2*16)/16*np.pi*2
    
    # pad zero in the z direction outside of the focal plane to mimic thin specimens
    target = np.pad(target[:,:,np.newaxis], ((0,0), (0,0), (50,49)), mode='constant')
    azimuth = np.pad(azimuth[:,:,np.newaxis], ((0,0), (0,0), (50,49)), mode='constant')
    inclination = np.pad(inclination[:,:,np.newaxis], ((0,0), (0,0), (50,49)), mode='constant')
else:
    print('sample_type needs to be 2D or 3D.')

# %%
# principal retardance, radial azimuth, and constant inclination to the pattern

n_o = n_media+0.01 
n_e = n_media+0.035

inclination = inclination
azimuth = (azimuth)%(2*np.pi)


no_map = np.zeros((N,M,L))
no_map[target > 0] = target[target > 0]*(n_o-n_media)
no_map += n_media
no_map_copy = no_map.copy()

ne_map = np.zeros((N,M,L))
ne_map[target > 0] = target[target > 0]*(n_e-n_media)
ne_map += n_media
ne_map_copy = ne_map.copy()

biref_map = ne_map_copy -  no_map_copy
## assign material on the top to be reverse optic sign ##
# no_map[:,:,L//2:] = ne_map_copy[:,:,L//2:].copy()
# ne_map[:,:,L//2:] = no_map_copy[:,:,L//2:].copy()
#########################################################

## assign material on the right to be reverse optic sign ##
# no_map[:,M//2:,:] = ne_map_copy[:,M//2:,:].copy()
# ne_map[:,M//2:,:] = no_map_copy[:,M//2:,:].copy()
###########################################################

# %% [markdown]
# ### Visualize sample properties

# %% [markdown]
# #### XY sections

# %%
wo.plot_multicolumn([target[:,:,z_layer], azimuth[:,:,z_layer]%(2*np.pi), inclination[:,:,z_layer]], origin='lower', size=5, num_col=3, titles=[f'target, z={z_layer}', 'azimuth', 'inclination'], set_title = True)
    
## animate through z-slices with this function ##
wo.parallel_4D_viewer(np.transpose(np.stack([biref_map, azimuth, inclination]),(3,0,1,2)), num_col=3, size=5, origin='lower',\
                     set_title=True, titles=[r'retardance',r'azimuth',r'inclination'])
#################################################
# Out:
# interactive(children=(IntSlider(value=0, description='stack_idx', max=99), Output()), _dom_classes=('widget-in…
# <function waveorder.visual.parallel_4D_viewer.<locals>.interact_plot(stack_idx)>

# %% [markdown]
# #### XZ sections

# %%
## xz section at y_layer ##
wo.plot_multicolumn([np.transpose(target[y_layer,:,:]), np.transpose(azimuth[y_layer,:,:])%(2*np.pi), np.transpose(inclination[y_layer,:,:])], origin='lower', size=5, num_col=3, titles=['retardance', 'azimuth', 'inclination'], set_title = True)
wo.parallel_4D_viewer(np.transpose(np.stack([target, azimuth%(2*np.pi), inclination]),(2,0,3,1)), num_col=3, size=5, origin='lower',\
                     set_title=True, titles=[r'retardance',r'azimuth',r'inclination'])
# Out:
# interactive(children=(IntSlider(value=0, description='stack_idx', max=199), Output()), _dom_classes=('widget-i…
# <function waveorder.visual.parallel_4D_viewer.<locals>.interact_plot(stack_idx)>

# %% [markdown]
# #### Principal retardance and 3D orientation in color

# %%
orientation_3D_image = np.transpose(np.array([azimuth%(2*np.pi)/2/np.pi, inclination,  np.clip((ne_map-no_map)*psz*2*np.pi/lambda_illu/np.pi/2*lambda_illu*1e3,0, 1.5)/1.5]),(3,1,2,0))
orientation_3D_image_RGB = wo.orientation_3D_to_rgb(orientation_3D_image, interp_belt = 20/180*np.pi, sat_factor = 1)

plt.figure(figsize=(10,10))
plt.imshow(orientation_3D_image_RGB[z_layer], origin='lower')
# wo.rgb_stack_viewer(orientation_3D_image_RGB, size=10, origin='lower')
plt.figure(figsize=(3,3))
wo.orientation_3D_colorwheel(wheelsize=128, circ_size=50, interp_belt=20/180*np.pi, sat_factor=1, discretize=True)


plt.figure(figsize=(10,10))
plt.imshow(orientation_3D_image_RGB[:,y_layer], origin='lower')
#wo.rgb_stack_viewer(np.transpose(orientation_3D_image_RGB,(1,0,2,3)), size=10, origin='lower')
plt.figure(figsize=(3,3))
wo.orientation_3D_colorwheel(wheelsize=128, circ_size=50, interp_belt=20/180*np.pi, sat_factor=1,  discretize=True)

# %% [markdown]
# #### Angular histogram of 3D orientation

# %%
wo.orientation_3D_hist(azimuth.flatten(), \
                       inclination.flatten(), \
                       np.abs(target).flatten(),\
                       bins=36, num_col=1, size=10, contour_level = 100, hist_cmap='gray', top_hemi=True)
# Out:
# (<Figure size 720x720 with 2 Axes>, <PolarAxesSubplot:>)

# %% [markdown]
# ## Compute permittivity and scattering potential tensors

# %% [markdown]
# ### assign the permittivity tensor according to the sample properties

# %%
epsilon_mean = (ne_map**2 + no_map**2)/2
epsilon_del = (ne_map**2 - no_map**2)/2

epsilon_tensor = np.zeros((3,3,N,M,L))
epsilon_tensor[0,0] = epsilon_mean - epsilon_del*(np.cos(inclination)**2 - np.sin(inclination)**2 * np.cos(2*azimuth))
epsilon_tensor[0,1] = epsilon_del * np.sin(inclination)**2 * np.sin(2*azimuth)
epsilon_tensor[0,2] = epsilon_del * np.sin(2*inclination) * np.cos(azimuth)

epsilon_tensor[1,0] = epsilon_del * np.sin(inclination)**2 * np.sin(2*azimuth)
epsilon_tensor[1,1] = epsilon_mean - epsilon_del*(np.cos(inclination)**2 + np.sin(inclination)**2 * np.cos(2*azimuth))
epsilon_tensor[1,2] = epsilon_del * np.sin(2*inclination) * np.sin(azimuth)

epsilon_tensor[2,0] = epsilon_del * np.sin(2*inclination) * np.cos(azimuth)
epsilon_tensor[2,1] = epsilon_del * np.sin(2*inclination) * np.sin(azimuth)
epsilon_tensor[2,2] = epsilon_mean + epsilon_del*np.cos(2*inclination)


wo.plot_multicolumn([epsilon_tensor[0,0,:,:,z_layer], epsilon_tensor[0,1,:,:,z_layer], epsilon_tensor[0,2,:,:,z_layer],\
                     epsilon_tensor[1,0,:,:,z_layer], epsilon_tensor[1,1,:,:,z_layer], epsilon_tensor[1,2,:,:,z_layer],\
                     epsilon_tensor[2,0,:,:,z_layer], epsilon_tensor[2,1,:,:,z_layer], epsilon_tensor[2,2,:,:,z_layer]], origin='lower', num_col=3, titles=[r'$\epsilon_{xx}$', r'$\epsilon_{xy}$',r'$\epsilon_{xz}$',\
                                                                                                                                                            r'$\epsilon_{yx}$', r'$\epsilon_{yy}$', r'$\epsilon_{yz}$',\
                                                                                                                                                            r'$\epsilon_{zx}$', r'$\epsilon_{zy}$', r'$\epsilon_{zz}$'],\
                                                                                                                                                            size=5, set_title = True)

# %%
## animate through z-slices with this function ##
wo.parallel_4D_viewer(np.transpose(epsilon_tensor.reshape((9, N, M, L)),(3,0,1,2)), num_col=3, size=5, origin='lower',\
                     set_title = True, titles=[r'$\epsilon_{xx}$', r'$\epsilon_{xy}$',r'$\epsilon_{xz}$',\
                                               r'$\epsilon_{yx}$', r'$\epsilon_{yy}$', r'$\epsilon_{yz}$',\
                                               r'$\epsilon_{zx}$', r'$\epsilon_{zy}$', r'$\epsilon_{zz}$'])
#################################################
# Out:
# interactive(children=(IntSlider(value=0, description='stack_idx', max=99), Output()), _dom_classes=('widget-in…
# <function waveorder.visual.parallel_4D_viewer.<locals>.interact_plot(stack_idx)>

# %% [markdown]
# ### Compute components of scattering potential tensor
# ($f_{0r}, f_{0i}, f_{1c}, f_{1s}, f_{2c},f_{2s}, f_{3}$)

# %%
# the corresponding components of the scattering potential tensor

del_f_component = np.zeros((7, N, M, L))
del_f_component[0] = np.real(((2*np.pi/lambda_illu)**2)*(n_media**2 -  epsilon_mean + epsilon_del*np.cos(inclination)**2))
del_f_component[1] = np.imag(((2*np.pi/lambda_illu)**2)*(n_media**2 -  epsilon_mean + epsilon_del*np.cos(inclination)**2))
del_f_component[2] = -((2*np.pi/lambda_illu)**2) * epsilon_del * np.sin(inclination)**2 * np.cos(2*azimuth)
del_f_component[3] = -((2*np.pi/lambda_illu)**2) * epsilon_del * np.sin(inclination)**2 * np.sin(2*azimuth)
del_f_component[4] = -((2*np.pi/lambda_illu)**2) * epsilon_del * np.sin(2*inclination) * np.cos(azimuth)
del_f_component[5] = -((2*np.pi/lambda_illu)**2) * epsilon_del * np.sin(2*inclination) * np.sin(azimuth)
del_f_component[6] = ((2*np.pi/lambda_illu)**2) * epsilon_del * (np.sin(inclination)**2 - 2*np.cos(inclination)**2)

# %%
wo.plot_multicolumn([del_f_component[0,:,:,z_layer], del_f_component[1,:,:,z_layer], del_f_component[2,:,:,z_layer], del_f_component[3,:,:,z_layer],\
                     del_f_component[4,:,:,z_layer], del_f_component[5,:,:,z_layer], del_f_component[6,:,:,z_layer]], origin='lower', num_col=4, titles=[r'$f_{0r}$', r'$f_{0i}$', r'$f_{1c}$',r'$f_{1s}$',\
                                                                                                                                                         r'$f_{2c}$', r'$f_{2s}$', r'$f_{3}$'],\
                                                                                                                                                         size=5, set_title = True)

# %%
## animate through z-slices with this function ##
wo.parallel_4D_viewer(np.transpose(del_f_component,(3,0,1,2)), num_col=4, size=5, origin='lower', \
                     set_title=True, titles=[r'$f_{0r}$', r'$f_{0i}$', r'$f_{1c}$',r'$f_{1s}$',\
                                             r'$f_{2c}$', r'$f_{2s}$', r'$f_{3}$'])
#################################################
# Out:
# interactive(children=(IntSlider(value=0, description='stack_idx', max=99), Output()), _dom_classes=('widget-in…
# <function waveorder.visual.parallel_4D_viewer.<locals>.interact_plot(stack_idx)>

# %% [markdown]
# ## Forward model of uPTI <br>(polarization-diverse, illumination-diverse, depth-diverse acquisition)

# %%
# DPC + BF illumination + PolState (sector illumination)

xx, yy, fxx, fyy = wo.gen_coordinate((N, M), ps)
Pupil_obj = wo.gen_Pupil(fxx, fyy, NA_obj/n_media, lambda_illu/n_media)
Source_support = wo.gen_Pupil(fxx, fyy, NA_illu/n_media, lambda_illu/n_media)

NAx_coord = lambda_illu/n_media*fxx
NAy_coord = lambda_illu/n_media*fyy


rotation_angle=[0, 45, 90, 135, 180, 225, 270, 315]


Source = np.zeros((len(rotation_angle)+1, N, M))
Source_cont = np.zeros_like(Source)

Source_BF = wo.gen_Pupil(fxx, fyy, NA_illu/n_media/2, lambda_illu/n_media)


Source_cont[-1] = Source_BF.copy()
Source[-1] = wo.Source_subsample(Source_BF, NAx_coord, NAy_coord, subsampled_NA = 0.1/n_media)



for i in range(len(rotation_angle)):
    deg = rotation_angle[i]
    Source_temp = np.zeros((N,M))
    Source_temp2 = np.zeros((N,M))
    Source_temp[fyy * np.cos(np.deg2rad(deg-22.5)) - fxx*np.sin(np.deg2rad(deg-22.5)) > 1e-10] = 1
    Source_temp2[fyy * np.cos(np.deg2rad(deg-135-22.5)) - fxx*np.sin(np.deg2rad(deg-135-22.5)) > 1e-10] = 1
    
    Source_cont[i] = Source_temp * Source_temp2 * Source_support 
    
    Source_discrete = wo.Source_subsample(Source_cont[i], NAx_coord, NAy_coord, subsampled_NA = 0.1/n_media)
    Source[i] = np.maximum(0,Source_discrete.copy())
    
    

Source_PolState = np.zeros((len(Source),2), complex)

for i in range(len(Source)):
    Source_PolState[i,0] = 1
    Source_PolState[i,1] = 1j

# %% [markdown]
# #### Circularly polarized illumination patterns

# %%
wo.plot_multicolumn(fftshift(Source_cont,axes=(1,2)), origin='lower', num_col=5)

# %%
# discretized illumination patterns used in simulation (faster forward model)
wo.plot_multicolumn(fftshift(Source,axes=(1,2)), origin='lower', num_col=5, size=10)

# %%
Source_PolState
# Out:
# array([[1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j]])

# %%
plt.figure(figsize=(10,10))
plt.imshow(fftshift(np.sum(Source,axis=0)), origin='lower')
np.sum(Source,axis=(1,2))
# Out:
# array([ 85.,  78.,  85.,  78.,  85.,  78.,  85.,  78., 160.])

# %% [markdown]
# #### Initialize microscope simulator with above source pattern and uniform imaging pupil

# %%
## initiate the simulator
simulator = wo.waveorder_microscopy_simulator((N,M), lambda_illu, ps, NA_obj, NA_illu, z_defocus, chi, \
                                n_media = n_media, illu_mode = 'Arbitrary', Source=Source, Source_PolState=Source_PolState, use_gpu=use_gpu, gpu_id=gpu_id)

# %% [markdown]
# ## Compute image volumes and Stokes volumes with vectorial simulation

# %%
# forward simulation done by vectorial SEAGLE implementation 
# (when itr_max = 0, we use the first Born approximation)

I_meas_SEAGLE, Stokes_SEAGLE = simulator.simulate_3D_vectorial_measurements_SEAGLE(epsilon_tensor, itr_max = 0, tolerance=1e-4, verbose=True)
# Out:
# Number of point sources considered (1 / 85) in pattern (1 / 9), elapsed time: 6.69
# Number of point sources considered (2 / 85) in pattern (1 / 9), elapsed time: 8.16
# Number of point sources considered (3 / 85) in pattern (1 / 9), elapsed time: 9.52
# Number of point sources considered (4 / 85) in pattern (1 / 9), elapsed time: 10.89
# Number of point sources considered (5 / 85) in pattern (1 / 9), elapsed time: 12.25
# Number of point sources considered (6 / 85) in pattern (1 / 9), elapsed time: 13.64
# Number of point sources considered (7 / 85) in pattern (1 / 9), elapsed time: 15.00
# Number of point sources considered (8 / 85) in pattern (1 / 9), elapsed time: 16.37
# Number of point sources considered (9 / 85) in pattern (1 / 9), elapsed time: 17.73
# Number of point sources considered (10 / 85) in pattern (1 / 9), elapsed time: 19.09
# Number of point sources considered (11 / 85) in pattern (1 / 9), elapsed time: 20.46
# Number of point sources considered (12 / 85) in pattern (1 / 9), elapsed time: 21.83
# Number of point sources considered (13 / 85) in pattern (1 / 9), elapsed time: 23.23
# Number of point sources considered (14 / 85) in pattern (1 / 9), elapsed time: 24.60
# Number of point sources considered (15 / 85) in pattern (1 / 9), elapsed time: 25.97
# Number of point sources considered (16 / 85) in pattern (1 / 9), elapsed time: 27.33
# Number of point sources considered (17 / 85) in pattern (1 / 9), elapsed time: 28.70
# Number of point sources considered (18 / 85) in pattern (1 / 9), elapsed time: 30.07
# Number of point sources considered (19 / 85) in pattern (1 / 9), elapsed time: 31.43
# Number of point sources considered (20 / 85) in pattern (1 / 9), elapsed time: 32.80
# Number of point sources considered (21 / 85) in pattern (1 / 9), elapsed time: 34.17
# Number of point sources considered (22 / 85) in pattern (1 / 9), elapsed time: 35.53
# Number of point sources considered (23 / 85) in pattern (1 / 9), elapsed time: 36.90
# Number of point sources considered (24 / 85) in pattern (1 / 9), elapsed time: 38.29
# Number of point sources considered (25 / 85) in pattern (1 / 9), elapsed time: 39.67
# Number of point sources considered (26 / 85) in pattern (1 / 9), elapsed time: 41.06
# Number of point sources considered (27 / 85) in pattern (1 / 9), elapsed time: 42.44
# Number of point sources considered (28 / 85) in pattern (1 / 9), elapsed time: 43.82
# Number of point sources considered (29 / 85) in pattern (1 / 9), elapsed time: 45.22
# Number of point sources considered (30 / 85) in pattern (1 / 9), elapsed time: 46.59
# Number of point sources considered (31 / 85) in pattern (1 / 9), elapsed time: 47.96
# Number of point sources considered (32 / 85) in pattern (1 / 9), elapsed time: 49.33
# Number of point sources considered (33 / 85) in pattern (1 / 9), elapsed time: 50.72
# Number of point sources considered (34 / 85) in pattern (1 / 9), elapsed time: 52.09
# Number of point sources considered (35 / 85) in pattern (1 / 9), elapsed time: 53.47
# Number of point sources considered (36 / 85) in pattern (1 / 9), elapsed time: 54.83
# Number of point sources considered (37 / 85) in pattern (1 / 9), elapsed time: 56.21
# Number of point sources considered (38 / 85) in pattern (1 / 9), elapsed time: 57.58
# Number of point sources considered (39 / 85) in pattern (1 / 9), elapsed time: 58.95
# Number of point sources considered (40 / 85) in pattern (1 / 9), elapsed time: 60.33
# Number of point sources considered (41 / 85) in pattern (1 / 9), elapsed time: 61.70
# Number of point sources considered (42 / 85) in pattern (1 / 9), elapsed time: 63.08
# Number of point sources considered (43 / 85) in pattern (1 / 9), elapsed time: 64.46
# Number of point sources considered (44 / 85) in pattern (1 / 9), elapsed time: 65.83
# Number of point sources considered (45 / 85) in pattern (1 / 9), elapsed time: 67.20
# Number of point sources considered (46 / 85) in pattern (1 / 9), elapsed time: 68.57
# Number of point sources considered (47 / 85) in pattern (1 / 9), elapsed time: 69.93
# Number of point sources considered (48 / 85) in pattern (1 / 9), elapsed time: 71.30
# Number of point sources considered (49 / 85) in pattern (1 / 9), elapsed time: 72.67
# Number of point sources considered (50 / 85) in pattern (1 / 9), elapsed time: 74.04
# Number of point sources considered (51 / 85) in pattern (1 / 9), elapsed time: 75.41
# Number of point sources considered (52 / 85) in pattern (1 / 9), elapsed time: 76.78
# Number of point sources considered (53 / 85) in pattern (1 / 9), elapsed time: 78.14
# Number of point sources considered (54 / 85) in pattern (1 / 9), elapsed time: 79.51
# Number of point sources considered (55 / 85) in pattern (1 / 9), elapsed time: 80.88
# Number of point sources considered (56 / 85) in pattern (1 / 9), elapsed time: 82.25
# Number of point sources considered (57 / 85) in pattern (1 / 9), elapsed time: 83.62
# Number of point sources considered (58 / 85) in pattern (1 / 9), elapsed time: 84.99
# Number of point sources considered (59 / 85) in pattern (1 / 9), elapsed time: 86.36
# Number of point sources considered (60 / 85) in pattern (1 / 9), elapsed time: 87.73
# Number of point sources considered (61 / 85) in pattern (1 / 9), elapsed time: 89.09
# Number of point sources considered (62 / 85) in pattern (1 / 9), elapsed time: 90.47
# Number of point sources considered (63 / 85) in pattern (1 / 9), elapsed time: 91.83
# Number of point sources considered (64 / 85) in pattern (1 / 9), elapsed time: 93.20
# Number of point sources considered (65 / 85) in pattern (1 / 9), elapsed time: 94.57
# Number of point sources considered (66 / 85) in pattern (1 / 9), elapsed time: 95.93
# Number of point sources considered (67 / 85) in pattern (1 / 9), elapsed time: 97.30
# Number of point sources considered (68 / 85) in pattern (1 / 9), elapsed time: 98.67
# Number of point sources considered (69 / 85) in pattern (1 / 9), elapsed time: 100.04
# Number of point sources considered (70 / 85) in pattern (1 / 9), elapsed time: 101.41
# Number of point sources considered (71 / 85) in pattern (1 / 9), elapsed time: 102.77
# Number of point sources considered (72 / 85) in pattern (1 / 9), elapsed time: 104.14
# Number of point sources considered (73 / 85) in pattern (1 / 9), elapsed time: 105.52
# Number of point sources considered (74 / 85) in pattern (1 / 9), elapsed time: 106.89
# Number of point sources considered (75 / 85) in pattern (1 / 9), elapsed time: 108.26
# Number of point sources considered (76 / 85) in pattern (1 / 9), elapsed time: 109.63
# Number of point sources considered (77 / 85) in pattern (1 / 9), elapsed time: 111.01
# Number of point sources considered (78 / 85) in pattern (1 / 9), elapsed time: 112.38
# Number of point sources considered (79 / 85) in pattern (1 / 9), elapsed time: 113.75
# Number of point sources considered (80 / 85) in pattern (1 / 9), elapsed time: 115.12
# Number of point sources considered (81 / 85) in pattern (1 / 9), elapsed time: 116.48
# Number of point sources considered (82 / 85) in pattern (1 / 9), elapsed time: 117.85
# Number of point sources considered (83 / 85) in pattern (1 / 9), elapsed time: 119.22
# Number of point sources considered (84 / 85) in pattern (1 / 9), elapsed time: 120.58
# Number of point sources considered (85 / 85) in pattern (1 / 9), elapsed time: 121.95
# Number of point sources considered (1 / 78) in pattern (2 / 9), elapsed time: 123.54
# Number of point sources considered (2 / 78) in pattern (2 / 9), elapsed time: 124.91
# Number of point sources considered (3 / 78) in pattern (2 / 9), elapsed time: 126.28
# Number of point sources considered (4 / 78) in pattern (2 / 9), elapsed time: 127.64
# Number of point sources considered (5 / 78) in pattern (2 / 9), elapsed time: 129.01
# Number of point sources considered (6 / 78) in pattern (2 / 9), elapsed time: 130.38
# Number of point sources considered (7 / 78) in pattern (2 / 9), elapsed time: 131.75
# Number of point sources considered (8 / 78) in pattern (2 / 9), elapsed time: 133.11
# Number of point sources considered (9 / 78) in pattern (2 / 9), elapsed time: 134.50
# Number of point sources considered (10 / 78) in pattern (2 / 9), elapsed time: 135.92
# Number of point sources considered (11 / 78) in pattern (2 / 9), elapsed time: 137.30
# Number of point sources considered (12 / 78) in pattern (2 / 9), elapsed time: 138.67
# Number of point sources considered (13 / 78) in pattern (2 / 9), elapsed time: 140.04
# Number of point sources considered (14 / 78) in pattern (2 / 9), elapsed time: 141.40
# Number of point sources considered (15 / 78) in pattern (2 / 9), elapsed time: 142.77
# Number of point sources considered (16 / 78) in pattern (2 / 9), elapsed time: 144.14
# Number of point sources considered (17 / 78) in pattern (2 / 9), elapsed time: 145.50
# Number of point sources considered (18 / 78) in pattern (2 / 9), elapsed time: 146.86
# Number of point sources considered (19 / 78) in pattern (2 / 9), elapsed time: 148.23
# Number of point sources considered (20 / 78) in pattern (2 / 9), elapsed time: 149.60
# Number of point sources considered (21 / 78) in pattern (2 / 9), elapsed time: 150.97
# Number of point sources considered (22 / 78) in pattern (2 / 9), elapsed time: 152.33
# Number of point sources considered (23 / 78) in pattern (2 / 9), elapsed time: 153.70
# Number of point sources considered (24 / 78) in pattern (2 / 9), elapsed time: 155.06
# Number of point sources considered (25 / 78) in pattern (2 / 9), elapsed time: 156.43
# Number of point sources considered (26 / 78) in pattern (2 / 9), elapsed time: 157.80
# Number of point sources considered (27 / 78) in pattern (2 / 9), elapsed time: 159.16
# Number of point sources considered (28 / 78) in pattern (2 / 9), elapsed time: 160.53
# Number of point sources considered (29 / 78) in pattern (2 / 9), elapsed time: 161.89
# Number of point sources considered (30 / 78) in pattern (2 / 9), elapsed time: 163.26
# Number of point sources considered (31 / 78) in pattern (2 / 9), elapsed time: 164.62
# Number of point sources considered (32 / 78) in pattern (2 / 9), elapsed time: 165.99
# Number of point sources considered (33 / 78) in pattern (2 / 9), elapsed time: 167.36
# Number of point sources considered (34 / 78) in pattern (2 / 9), elapsed time: 168.72
# Number of point sources considered (35 / 78) in pattern (2 / 9), elapsed time: 170.10
# Number of point sources considered (36 / 78) in pattern (2 / 9), elapsed time: 171.47
# Number of point sources considered (37 / 78) in pattern (2 / 9), elapsed time: 172.83
# Number of point sources considered (38 / 78) in pattern (2 / 9), elapsed time: 174.22
# Number of point sources considered (39 / 78) in pattern (2 / 9), elapsed time: 175.59
# Number of point sources considered (40 / 78) in pattern (2 / 9), elapsed time: 176.95
# Number of point sources considered (41 / 78) in pattern (2 / 9), elapsed time: 178.32
# Number of point sources considered (42 / 78) in pattern (2 / 9), elapsed time: 179.69
# Number of point sources considered (43 / 78) in pattern (2 / 9), elapsed time: 181.06
# Number of point sources considered (44 / 78) in pattern (2 / 9), elapsed time: 182.42
# Number of point sources considered (45 / 78) in pattern (2 / 9), elapsed time: 183.79
# Number of point sources considered (46 / 78) in pattern (2 / 9), elapsed time: 185.16
# Number of point sources considered (47 / 78) in pattern (2 / 9), elapsed time: 186.53
# Number of point sources considered (48 / 78) in pattern (2 / 9), elapsed time: 187.90
# Number of point sources considered (49 / 78) in pattern (2 / 9), elapsed time: 189.26
# Number of point sources considered (50 / 78) in pattern (2 / 9), elapsed time: 190.63
# Number of point sources considered (51 / 78) in pattern (2 / 9), elapsed time: 192.00
# Number of point sources considered (52 / 78) in pattern (2 / 9), elapsed time: 193.37
# Number of point sources considered (53 / 78) in pattern (2 / 9), elapsed time: 194.73
# Number of point sources considered (54 / 78) in pattern (2 / 9), elapsed time: 196.10
# Number of point sources considered (55 / 78) in pattern (2 / 9), elapsed time: 197.47
# Number of point sources considered (56 / 78) in pattern (2 / 9), elapsed time: 198.83
# Number of point sources considered (57 / 78) in pattern (2 / 9), elapsed time: 200.20
# Number of point sources considered (58 / 78) in pattern (2 / 9), elapsed time: 201.56
# Number of point sources considered (59 / 78) in pattern (2 / 9), elapsed time: 202.93
# Number of point sources considered (60 / 78) in pattern (2 / 9), elapsed time: 204.31
# Number of point sources considered (61 / 78) in pattern (2 / 9), elapsed time: 205.68
# Number of point sources considered (62 / 78) in pattern (2 / 9), elapsed time: 207.04
# Number of point sources considered (63 / 78) in pattern (2 / 9), elapsed time: 208.41
# Number of point sources considered (64 / 78) in pattern (2 / 9), elapsed time: 209.78
# Number of point sources considered (65 / 78) in pattern (2 / 9), elapsed time: 211.14
# Number of point sources considered (66 / 78) in pattern (2 / 9), elapsed time: 212.50
# Number of point sources considered (67 / 78) in pattern (2 / 9), elapsed time: 213.88
# Number of point sources considered (68 / 78) in pattern (2 / 9), elapsed time: 215.24
# Number of point sources considered (69 / 78) in pattern (2 / 9), elapsed time: 216.62
# Number of point sources considered (70 / 78) in pattern (2 / 9), elapsed time: 217.99
# Number of point sources considered (71 / 78) in pattern (2 / 9), elapsed time: 219.35
# Number of point sources considered (72 / 78) in pattern (2 / 9), elapsed time: 220.72
# Number of point sources considered (73 / 78) in pattern (2 / 9), elapsed time: 222.09
# Number of point sources considered (74 / 78) in pattern (2 / 9), elapsed time: 223.46
# Number of point sources considered (75 / 78) in pattern (2 / 9), elapsed time: 224.84
# Number of point sources considered (76 / 78) in pattern (2 / 9), elapsed time: 226.21
# Number of point sources considered (77 / 78) in pattern (2 / 9), elapsed time: 227.57
# Number of point sources considered (78 / 78) in pattern (2 / 9), elapsed time: 228.96
# Number of point sources considered (1 / 85) in pattern (3 / 9), elapsed time: 230.58
# Number of point sources considered (2 / 85) in pattern (3 / 9), elapsed time: 231.97
# Number of point sources considered (3 / 85) in pattern (3 / 9), elapsed time: 233.37
# Number of point sources considered (4 / 85) in pattern (3 / 9), elapsed time: 234.76
# Number of point sources considered (5 / 85) in pattern (3 / 9), elapsed time: 236.15
# Number of point sources considered (6 / 85) in pattern (3 / 9), elapsed time: 237.54
# Number of point sources considered (7 / 85) in pattern (3 / 9), elapsed time: 238.93
# Number of point sources considered (8 / 85) in pattern (3 / 9), elapsed time: 240.32
# Number of point sources considered (9 / 85) in pattern (3 / 9), elapsed time: 241.71
# Number of point sources considered (10 / 85) in pattern (3 / 9), elapsed time: 243.09
# Number of point sources considered (11 / 85) in pattern (3 / 9), elapsed time: 244.48
# Number of point sources considered (12 / 85) in pattern (3 / 9), elapsed time: 245.86
# Number of point sources considered (13 / 85) in pattern (3 / 9), elapsed time: 247.26
# Number of point sources considered (14 / 85) in pattern (3 / 9), elapsed time: 248.65
# Number of point sources considered (15 / 85) in pattern (3 / 9), elapsed time: 250.04
# Number of point sources considered (16 / 85) in pattern (3 / 9), elapsed time: 251.43
# Number of point sources considered (17 / 85) in pattern (3 / 9), elapsed time: 252.81
# Number of point sources considered (18 / 85) in pattern (3 / 9), elapsed time: 254.20
# Number of point sources considered (19 / 85) in pattern (3 / 9), elapsed time: 255.59
# Number of point sources considered (20 / 85) in pattern (3 / 9), elapsed time: 256.97
# Number of point sources considered (21 / 85) in pattern (3 / 9), elapsed time: 258.37
# Number of point sources considered (22 / 85) in pattern (3 / 9), elapsed time: 259.77
# Number of point sources considered (23 / 85) in pattern (3 / 9), elapsed time: 261.16
# Number of point sources considered (24 / 85) in pattern (3 / 9), elapsed time: 262.55
# Number of point sources considered (25 / 85) in pattern (3 / 9), elapsed time: 263.93
# Number of point sources considered (26 / 85) in pattern (3 / 9), elapsed time: 265.31
# Number of point sources considered (27 / 85) in pattern (3 / 9), elapsed time: 266.70
# Number of point sources considered (28 / 85) in pattern (3 / 9), elapsed time: 268.09
# Number of point sources considered (29 / 85) in pattern (3 / 9), elapsed time: 269.48
# Number of point sources considered (30 / 85) in pattern (3 / 9), elapsed time: 270.87
# Number of point sources considered (31 / 85) in pattern (3 / 9), elapsed time: 272.27
# Number of point sources considered (32 / 85) in pattern (3 / 9), elapsed time: 273.64
# Number of point sources considered (33 / 85) in pattern (3 / 9), elapsed time: 275.03
# Number of point sources considered (34 / 85) in pattern (3 / 9), elapsed time: 276.42
# Number of point sources considered (35 / 85) in pattern (3 / 9), elapsed time: 277.81
# Number of point sources considered (36 / 85) in pattern (3 / 9), elapsed time: 279.20
# Number of point sources considered (37 / 85) in pattern (3 / 9), elapsed time: 280.59
# Number of point sources considered (38 / 85) in pattern (3 / 9), elapsed time: 281.97
# Number of point sources considered (39 / 85) in pattern (3 / 9), elapsed time: 283.36
# Number of point sources considered (40 / 85) in pattern (3 / 9), elapsed time: 284.74
# Number of point sources considered (41 / 85) in pattern (3 / 9), elapsed time: 286.13
# Number of point sources considered (42 / 85) in pattern (3 / 9), elapsed time: 287.53
# Number of point sources considered (43 / 85) in pattern (3 / 9), elapsed time: 288.92
# Number of point sources considered (44 / 85) in pattern (3 / 9), elapsed time: 290.31
# Number of point sources considered (45 / 85) in pattern (3 / 9), elapsed time: 291.70
# Number of point sources considered (46 / 85) in pattern (3 / 9), elapsed time: 293.08
# Number of point sources considered (47 / 85) in pattern (3 / 9), elapsed time: 294.47
# Number of point sources considered (48 / 85) in pattern (3 / 9), elapsed time: 295.86
# Number of point sources considered (49 / 85) in pattern (3 / 9), elapsed time: 297.24
# Number of point sources considered (50 / 85) in pattern (3 / 9), elapsed time: 298.64
# Number of point sources considered (51 / 85) in pattern (3 / 9), elapsed time: 300.03
# Number of point sources considered (52 / 85) in pattern (3 / 9), elapsed time: 301.42
# Number of point sources considered (53 / 85) in pattern (3 / 9), elapsed time: 302.80
# Number of point sources considered (54 / 85) in pattern (3 / 9), elapsed time: 304.19
# Number of point sources considered (55 / 85) in pattern (3 / 9), elapsed time: 305.58
# Number of point sources considered (56 / 85) in pattern (3 / 9), elapsed time: 306.97
# Number of point sources considered (57 / 85) in pattern (3 / 9), elapsed time: 308.36
# Number of point sources considered (58 / 85) in pattern (3 / 9), elapsed time: 309.75
# Number of point sources considered (59 / 85) in pattern (3 / 9), elapsed time: 311.14
# Number of point sources considered (60 / 85) in pattern (3 / 9), elapsed time: 312.52
# Number of point sources considered (61 / 85) in pattern (3 / 9), elapsed time: 313.91
# Number of point sources considered (62 / 85) in pattern (3 / 9), elapsed time: 315.29
# Number of point sources considered (63 / 85) in pattern (3 / 9), elapsed time: 316.68
# Number of point sources considered (64 / 85) in pattern (3 / 9), elapsed time: 318.08
# Number of point sources considered (65 / 85) in pattern (3 / 9), elapsed time: 319.46
# Number of point sources considered (66 / 85) in pattern (3 / 9), elapsed time: 320.85
# Number of point sources considered (67 / 85) in pattern (3 / 9), elapsed time: 322.23
# Number of point sources considered (68 / 85) in pattern (3 / 9), elapsed time: 323.62
# Number of point sources considered (69 / 85) in pattern (3 / 9), elapsed time: 325.01
# Number of point sources considered (70 / 85) in pattern (3 / 9), elapsed time: 326.40
# Number of point sources considered (71 / 85) in pattern (3 / 9), elapsed time: 327.79
# Number of point sources considered (72 / 85) in pattern (3 / 9), elapsed time: 329.17
# Number of point sources considered (73 / 85) in pattern (3 / 9), elapsed time: 330.56
# Number of point sources considered (74 / 85) in pattern (3 / 9), elapsed time: 331.95
# Number of point sources considered (75 / 85) in pattern (3 / 9), elapsed time: 333.34
# Number of point sources considered (76 / 85) in pattern (3 / 9), elapsed time: 334.73
# Number of point sources considered (77 / 85) in pattern (3 / 9), elapsed time: 336.11
# Number of point sources considered (78 / 85) in pattern (3 / 9), elapsed time: 337.50
# Number of point sources considered (79 / 85) in pattern (3 / 9), elapsed time: 338.89
# Number of point sources considered (80 / 85) in pattern (3 / 9), elapsed time: 340.28
# Number of point sources considered (81 / 85) in pattern (3 / 9), elapsed time: 341.67
# Number of point sources considered (82 / 85) in pattern (3 / 9), elapsed time: 343.06
# Number of point sources considered (83 / 85) in pattern (3 / 9), elapsed time: 344.45
# Number of point sources considered (84 / 85) in pattern (3 / 9), elapsed time: 345.84
# Number of point sources considered (85 / 85) in pattern (3 / 9), elapsed time: 347.22
# Number of point sources considered (1 / 78) in pattern (4 / 9), elapsed time: 348.83
# Number of point sources considered (2 / 78) in pattern (4 / 9), elapsed time: 350.21
# Number of point sources considered (3 / 78) in pattern (4 / 9), elapsed time: 351.58
# Number of point sources considered (4 / 78) in pattern (4 / 9), elapsed time: 352.95
# Number of point sources considered (5 / 78) in pattern (4 / 9), elapsed time: 354.31
# Number of point sources considered (6 / 78) in pattern (4 / 9), elapsed time: 355.68
# Number of point sources considered (7 / 78) in pattern (4 / 9), elapsed time: 357.05
# Number of point sources considered (8 / 78) in pattern (4 / 9), elapsed time: 358.42
# Number of point sources considered (9 / 78) in pattern (4 / 9), elapsed time: 359.78
# Number of point sources considered (10 / 78) in pattern (4 / 9), elapsed time: 361.15
# Number of point sources considered (11 / 78) in pattern (4 / 9), elapsed time: 362.53
# Number of point sources considered (12 / 78) in pattern (4 / 9), elapsed time: 363.89
# Number of point sources considered (13 / 78) in pattern (4 / 9), elapsed time: 365.27
# Number of point sources considered (14 / 78) in pattern (4 / 9), elapsed time: 366.63
# Number of point sources considered (15 / 78) in pattern (4 / 9), elapsed time: 368.00
# Number of point sources considered (16 / 78) in pattern (4 / 9), elapsed time: 369.37
# Number of point sources considered (17 / 78) in pattern (4 / 9), elapsed time: 370.73
# Number of point sources considered (18 / 78) in pattern (4 / 9), elapsed time: 372.10
# Number of point sources considered (19 / 78) in pattern (4 / 9), elapsed time: 373.47
# Number of point sources considered (20 / 78) in pattern (4 / 9), elapsed time: 374.84
# Number of point sources considered (21 / 78) in pattern (4 / 9), elapsed time: 376.20
# Number of point sources considered (22 / 78) in pattern (4 / 9), elapsed time: 377.57
# Number of point sources considered (23 / 78) in pattern (4 / 9), elapsed time: 378.94
# Number of point sources considered (24 / 78) in pattern (4 / 9), elapsed time: 380.30
# Number of point sources considered (25 / 78) in pattern (4 / 9), elapsed time: 381.67
# Number of point sources considered (26 / 78) in pattern (4 / 9), elapsed time: 383.03
# Number of point sources considered (27 / 78) in pattern (4 / 9), elapsed time: 384.41
# Number of point sources considered (28 / 78) in pattern (4 / 9), elapsed time: 385.77
# Number of point sources considered (29 / 78) in pattern (4 / 9), elapsed time: 387.14
# Number of point sources considered (30 / 78) in pattern (4 / 9), elapsed time: 388.51
# Number of point sources considered (31 / 78) in pattern (4 / 9), elapsed time: 389.88
# Number of point sources considered (32 / 78) in pattern (4 / 9), elapsed time: 391.25
# Number of point sources considered (33 / 78) in pattern (4 / 9), elapsed time: 392.62
# Number of point sources considered (34 / 78) in pattern (4 / 9), elapsed time: 393.98
# Number of point sources considered (35 / 78) in pattern (4 / 9), elapsed time: 395.35
# Number of point sources considered (36 / 78) in pattern (4 / 9), elapsed time: 396.72
# Number of point sources considered (37 / 78) in pattern (4 / 9), elapsed time: 398.08
# Number of point sources considered (38 / 78) in pattern (4 / 9), elapsed time: 399.45
# Number of point sources considered (39 / 78) in pattern (4 / 9), elapsed time: 400.82
# Number of point sources considered (40 / 78) in pattern (4 / 9), elapsed time: 402.18
# Number of point sources considered (41 / 78) in pattern (4 / 9), elapsed time: 403.55
# Number of point sources considered (42 / 78) in pattern (4 / 9), elapsed time: 404.91
# Number of point sources considered (43 / 78) in pattern (4 / 9), elapsed time: 406.28
# Number of point sources considered (44 / 78) in pattern (4 / 9), elapsed time: 407.65
# Number of point sources considered (45 / 78) in pattern (4 / 9), elapsed time: 409.03
# Number of point sources considered (46 / 78) in pattern (4 / 9), elapsed time: 410.42
# Number of point sources considered (47 / 78) in pattern (4 / 9), elapsed time: 411.79
# Number of point sources considered (48 / 78) in pattern (4 / 9), elapsed time: 413.16
# Number of point sources considered (49 / 78) in pattern (4 / 9), elapsed time: 414.52
# Number of point sources considered (50 / 78) in pattern (4 / 9), elapsed time: 415.89
# Number of point sources considered (51 / 78) in pattern (4 / 9), elapsed time: 417.26
# Number of point sources considered (52 / 78) in pattern (4 / 9), elapsed time: 418.62
# Number of point sources considered (53 / 78) in pattern (4 / 9), elapsed time: 419.99
# Number of point sources considered (54 / 78) in pattern (4 / 9), elapsed time: 421.35
# Number of point sources considered (55 / 78) in pattern (4 / 9), elapsed time: 422.72
# Number of point sources considered (56 / 78) in pattern (4 / 9), elapsed time: 424.09
# Number of point sources considered (57 / 78) in pattern (4 / 9), elapsed time: 425.46
# Number of point sources considered (58 / 78) in pattern (4 / 9), elapsed time: 426.83
# Number of point sources considered (59 / 78) in pattern (4 / 9), elapsed time: 428.19
# Number of point sources considered (60 / 78) in pattern (4 / 9), elapsed time: 429.56
# Number of point sources considered (61 / 78) in pattern (4 / 9), elapsed time: 430.93
# Number of point sources considered (62 / 78) in pattern (4 / 9), elapsed time: 432.30
# Number of point sources considered (63 / 78) in pattern (4 / 9), elapsed time: 433.66
# Number of point sources considered (64 / 78) in pattern (4 / 9), elapsed time: 435.04
# Number of point sources considered (65 / 78) in pattern (4 / 9), elapsed time: 436.41
# Number of point sources considered (66 / 78) in pattern (4 / 9), elapsed time: 437.77
# Number of point sources considered (67 / 78) in pattern (4 / 9), elapsed time: 439.15
# Number of point sources considered (68 / 78) in pattern (4 / 9), elapsed time: 440.51
# Number of point sources considered (69 / 78) in pattern (4 / 9), elapsed time: 441.88
# Number of point sources considered (70 / 78) in pattern (4 / 9), elapsed time: 443.25
# Number of point sources considered (71 / 78) in pattern (4 / 9), elapsed time: 444.61
# Number of point sources considered (72 / 78) in pattern (4 / 9), elapsed time: 445.98
# Number of point sources considered (73 / 78) in pattern (4 / 9), elapsed time: 447.34
# Number of point sources considered (74 / 78) in pattern (4 / 9), elapsed time: 448.71
# Number of point sources considered (75 / 78) in pattern (4 / 9), elapsed time: 450.09
# Number of point sources considered (76 / 78) in pattern (4 / 9), elapsed time: 451.46
# Number of point sources considered (77 / 78) in pattern (4 / 9), elapsed time: 452.82
# Number of point sources considered (78 / 78) in pattern (4 / 9), elapsed time: 454.19
# Number of point sources considered (1 / 85) in pattern (5 / 9), elapsed time: 455.78
# Number of point sources considered (2 / 85) in pattern (5 / 9), elapsed time: 457.15
# Number of point sources considered (3 / 85) in pattern (5 / 9), elapsed time: 458.52
# Number of point sources considered (4 / 85) in pattern (5 / 9), elapsed time: 459.88
# Number of point sources considered (5 / 85) in pattern (5 / 9), elapsed time: 461.25
# Number of point sources considered (6 / 85) in pattern (5 / 9), elapsed time: 462.63
# Number of point sources considered (7 / 85) in pattern (5 / 9), elapsed time: 464.00
# Number of point sources considered (8 / 85) in pattern (5 / 9), elapsed time: 465.37
# Number of point sources considered (9 / 85) in pattern (5 / 9), elapsed time: 466.74
# Number of point sources considered (10 / 85) in pattern (5 / 9), elapsed time: 468.11
# Number of point sources considered (11 / 85) in pattern (5 / 9), elapsed time: 469.49
# Number of point sources considered (12 / 85) in pattern (5 / 9), elapsed time: 470.87
# Number of point sources considered (13 / 85) in pattern (5 / 9), elapsed time: 472.25
# Number of point sources considered (14 / 85) in pattern (5 / 9), elapsed time: 473.61
# Number of point sources considered (15 / 85) in pattern (5 / 9), elapsed time: 474.98
# Number of point sources considered (16 / 85) in pattern (5 / 9), elapsed time: 476.35
# Number of point sources considered (17 / 85) in pattern (5 / 9), elapsed time: 477.73
# Number of point sources considered (18 / 85) in pattern (5 / 9), elapsed time: 479.09
# Number of point sources considered (19 / 85) in pattern (5 / 9), elapsed time: 480.47
# Number of point sources considered (20 / 85) in pattern (5 / 9), elapsed time: 481.83
# Number of point sources considered (21 / 85) in pattern (5 / 9), elapsed time: 483.21
# Number of point sources considered (22 / 85) in pattern (5 / 9), elapsed time: 484.58
# Number of point sources considered (23 / 85) in pattern (5 / 9), elapsed time: 485.95
# Number of point sources considered (24 / 85) in pattern (5 / 9), elapsed time: 487.31
# Number of point sources considered (25 / 85) in pattern (5 / 9), elapsed time: 488.69
# Number of point sources considered (26 / 85) in pattern (5 / 9), elapsed time: 490.05
# Number of point sources considered (27 / 85) in pattern (5 / 9), elapsed time: 491.42
# Number of point sources considered (28 / 85) in pattern (5 / 9), elapsed time: 492.78
# Number of point sources considered (29 / 85) in pattern (5 / 9), elapsed time: 494.15
# Number of point sources considered (30 / 85) in pattern (5 / 9), elapsed time: 495.51
# Number of point sources considered (31 / 85) in pattern (5 / 9), elapsed time: 496.88
# Number of point sources considered (32 / 85) in pattern (5 / 9), elapsed time: 498.24
# Number of point sources considered (33 / 85) in pattern (5 / 9), elapsed time: 499.61
# Number of point sources considered (34 / 85) in pattern (5 / 9), elapsed time: 500.98
# Number of point sources considered (35 / 85) in pattern (5 / 9), elapsed time: 502.34
# Number of point sources considered (36 / 85) in pattern (5 / 9), elapsed time: 503.71
# Number of point sources considered (37 / 85) in pattern (5 / 9), elapsed time: 505.07
# Number of point sources considered (38 / 85) in pattern (5 / 9), elapsed time: 506.44
# Number of point sources considered (39 / 85) in pattern (5 / 9), elapsed time: 507.80
# Number of point sources considered (40 / 85) in pattern (5 / 9), elapsed time: 509.16
# Number of point sources considered (41 / 85) in pattern (5 / 9), elapsed time: 510.53
# Number of point sources considered (42 / 85) in pattern (5 / 9), elapsed time: 511.89
# Number of point sources considered (43 / 85) in pattern (5 / 9), elapsed time: 513.27
# Number of point sources considered (44 / 85) in pattern (5 / 9), elapsed time: 514.64
# Number of point sources considered (45 / 85) in pattern (5 / 9), elapsed time: 516.00
# Number of point sources considered (46 / 85) in pattern (5 / 9), elapsed time: 517.36
# Number of point sources considered (47 / 85) in pattern (5 / 9), elapsed time: 518.73
# Number of point sources considered (48 / 85) in pattern (5 / 9), elapsed time: 520.09
# Number of point sources considered (49 / 85) in pattern (5 / 9), elapsed time: 521.46
# Number of point sources considered (50 / 85) in pattern (5 / 9), elapsed time: 522.83
# Number of point sources considered (51 / 85) in pattern (5 / 9), elapsed time: 524.19
# Number of point sources considered (52 / 85) in pattern (5 / 9), elapsed time: 525.56
# Number of point sources considered (53 / 85) in pattern (5 / 9), elapsed time: 526.93
# Number of point sources considered (54 / 85) in pattern (5 / 9), elapsed time: 528.30
# Number of point sources considered (55 / 85) in pattern (5 / 9), elapsed time: 529.66
# Number of point sources considered (56 / 85) in pattern (5 / 9), elapsed time: 531.04
# Number of point sources considered (57 / 85) in pattern (5 / 9), elapsed time: 532.41
# Number of point sources considered (58 / 85) in pattern (5 / 9), elapsed time: 533.78
# Number of point sources considered (59 / 85) in pattern (5 / 9), elapsed time: 535.14
# Number of point sources considered (60 / 85) in pattern (5 / 9), elapsed time: 536.51
# Number of point sources considered (61 / 85) in pattern (5 / 9), elapsed time: 537.87
# Number of point sources considered (62 / 85) in pattern (5 / 9), elapsed time: 539.23
# Number of point sources considered (63 / 85) in pattern (5 / 9), elapsed time: 540.60
# Number of point sources considered (64 / 85) in pattern (5 / 9), elapsed time: 541.97
# Number of point sources considered (65 / 85) in pattern (5 / 9), elapsed time: 543.33
# Number of point sources considered (66 / 85) in pattern (5 / 9), elapsed time: 544.70
# Number of point sources considered (67 / 85) in pattern (5 / 9), elapsed time: 546.07
# Number of point sources considered (68 / 85) in pattern (5 / 9), elapsed time: 547.43
# Number of point sources considered (69 / 85) in pattern (5 / 9), elapsed time: 548.80
# Number of point sources considered (70 / 85) in pattern (5 / 9), elapsed time: 550.16
# Number of point sources considered (71 / 85) in pattern (5 / 9), elapsed time: 551.53
# Number of point sources considered (72 / 85) in pattern (5 / 9), elapsed time: 552.90
# Number of point sources considered (73 / 85) in pattern (5 / 9), elapsed time: 554.26
# Number of point sources considered (74 / 85) in pattern (5 / 9), elapsed time: 555.62
# Number of point sources considered (75 / 85) in pattern (5 / 9), elapsed time: 556.99
# Number of point sources considered (76 / 85) in pattern (5 / 9), elapsed time: 558.36
# Number of point sources considered (77 / 85) in pattern (5 / 9), elapsed time: 559.72
# Number of point sources considered (78 / 85) in pattern (5 / 9), elapsed time: 561.09
# Number of point sources considered (79 / 85) in pattern (5 / 9), elapsed time: 562.45
# Number of point sources considered (80 / 85) in pattern (5 / 9), elapsed time: 563.82
# Number of point sources considered (81 / 85) in pattern (5 / 9), elapsed time: 565.19
# Number of point sources considered (82 / 85) in pattern (5 / 9), elapsed time: 566.55
# Number of point sources considered (83 / 85) in pattern (5 / 9), elapsed time: 567.91
# Number of point sources considered (84 / 85) in pattern (5 / 9), elapsed time: 569.29
# Number of point sources considered (85 / 85) in pattern (5 / 9), elapsed time: 570.65
# Number of point sources considered (1 / 78) in pattern (6 / 9), elapsed time: 572.23
# Number of point sources considered (2 / 78) in pattern (6 / 9), elapsed time: 573.60
# Number of point sources considered (3 / 78) in pattern (6 / 9), elapsed time: 574.96
# Number of point sources considered (4 / 78) in pattern (6 / 9), elapsed time: 576.34
# Number of point sources considered (5 / 78) in pattern (6 / 9), elapsed time: 577.70
# Number of point sources considered (6 / 78) in pattern (6 / 9), elapsed time: 579.06
# Number of point sources considered (7 / 78) in pattern (6 / 9), elapsed time: 580.42
# Number of point sources considered (8 / 78) in pattern (6 / 9), elapsed time: 581.78
# Number of point sources considered (9 / 78) in pattern (6 / 9), elapsed time: 583.14
# Number of point sources considered (10 / 78) in pattern (6 / 9), elapsed time: 584.51
# Number of point sources considered (11 / 78) in pattern (6 / 9), elapsed time: 585.87
# Number of point sources considered (12 / 78) in pattern (6 / 9), elapsed time: 587.23
# Number of point sources considered (13 / 78) in pattern (6 / 9), elapsed time: 588.60
# Number of point sources considered (14 / 78) in pattern (6 / 9), elapsed time: 589.97
# Number of point sources considered (15 / 78) in pattern (6 / 9), elapsed time: 591.33
# Number of point sources considered (16 / 78) in pattern (6 / 9), elapsed time: 592.70
# Number of point sources considered (17 / 78) in pattern (6 / 9), elapsed time: 594.06
# Number of point sources considered (18 / 78) in pattern (6 / 9), elapsed time: 595.43
# Number of point sources considered (19 / 78) in pattern (6 / 9), elapsed time: 596.79
# Number of point sources considered (20 / 78) in pattern (6 / 9), elapsed time: 598.16
# Number of point sources considered (21 / 78) in pattern (6 / 9), elapsed time: 599.53
# Number of point sources considered (22 / 78) in pattern (6 / 9), elapsed time: 600.89
# Number of point sources considered (23 / 78) in pattern (6 / 9), elapsed time: 602.25
# Number of point sources considered (24 / 78) in pattern (6 / 9), elapsed time: 603.61
# Number of point sources considered (25 / 78) in pattern (6 / 9), elapsed time: 604.98
# Number of point sources considered (26 / 78) in pattern (6 / 9), elapsed time: 606.34
# Number of point sources considered (27 / 78) in pattern (6 / 9), elapsed time: 607.71
# Number of point sources considered (28 / 78) in pattern (6 / 9), elapsed time: 609.08
# Number of point sources considered (29 / 78) in pattern (6 / 9), elapsed time: 610.44
# Number of point sources considered (30 / 78) in pattern (6 / 9), elapsed time: 611.81
# Number of point sources considered (31 / 78) in pattern (6 / 9), elapsed time: 613.18
# Number of point sources considered (32 / 78) in pattern (6 / 9), elapsed time: 614.54
# Number of point sources considered (33 / 78) in pattern (6 / 9), elapsed time: 615.90
# Number of point sources considered (34 / 78) in pattern (6 / 9), elapsed time: 617.27
# Number of point sources considered (35 / 78) in pattern (6 / 9), elapsed time: 618.64
# Number of point sources considered (36 / 78) in pattern (6 / 9), elapsed time: 620.00
# Number of point sources considered (37 / 78) in pattern (6 / 9), elapsed time: 621.37
# Number of point sources considered (38 / 78) in pattern (6 / 9), elapsed time: 622.74
# Number of point sources considered (39 / 78) in pattern (6 / 9), elapsed time: 624.10
# Number of point sources considered (40 / 78) in pattern (6 / 9), elapsed time: 625.47
# Number of point sources considered (41 / 78) in pattern (6 / 9), elapsed time: 626.84
# Number of point sources considered (42 / 78) in pattern (6 / 9), elapsed time: 628.20
# Number of point sources considered (43 / 78) in pattern (6 / 9), elapsed time: 629.57
# Number of point sources considered (44 / 78) in pattern (6 / 9), elapsed time: 630.94
# Number of point sources considered (45 / 78) in pattern (6 / 9), elapsed time: 632.30
# Number of point sources considered (46 / 78) in pattern (6 / 9), elapsed time: 633.67
# Number of point sources considered (47 / 78) in pattern (6 / 9), elapsed time: 635.04
# Number of point sources considered (48 / 78) in pattern (6 / 9), elapsed time: 636.40
# Number of point sources considered (49 / 78) in pattern (6 / 9), elapsed time: 637.77
# Number of point sources considered (50 / 78) in pattern (6 / 9), elapsed time: 639.14
# Number of point sources considered (51 / 78) in pattern (6 / 9), elapsed time: 640.51
# Number of point sources considered (52 / 78) in pattern (6 / 9), elapsed time: 641.89
# Number of point sources considered (53 / 78) in pattern (6 / 9), elapsed time: 643.26
# Number of point sources considered (54 / 78) in pattern (6 / 9), elapsed time: 644.62
# Number of point sources considered (55 / 78) in pattern (6 / 9), elapsed time: 646.00
# Number of point sources considered (56 / 78) in pattern (6 / 9), elapsed time: 647.37
# Number of point sources considered (57 / 78) in pattern (6 / 9), elapsed time: 648.73
# Number of point sources considered (58 / 78) in pattern (6 / 9), elapsed time: 650.11
# Number of point sources considered (59 / 78) in pattern (6 / 9), elapsed time: 651.48
# Number of point sources considered (60 / 78) in pattern (6 / 9), elapsed time: 652.85
# Number of point sources considered (61 / 78) in pattern (6 / 9), elapsed time: 654.22
# Number of point sources considered (62 / 78) in pattern (6 / 9), elapsed time: 655.59
# Number of point sources considered (63 / 78) in pattern (6 / 9), elapsed time: 656.96
# Number of point sources considered (64 / 78) in pattern (6 / 9), elapsed time: 658.33
# Number of point sources considered (65 / 78) in pattern (6 / 9), elapsed time: 659.69
# Number of point sources considered (66 / 78) in pattern (6 / 9), elapsed time: 661.07
# Number of point sources considered (67 / 78) in pattern (6 / 9), elapsed time: 662.43
# Number of point sources considered (68 / 78) in pattern (6 / 9), elapsed time: 663.80
# Number of point sources considered (69 / 78) in pattern (6 / 9), elapsed time: 665.18
# Number of point sources considered (70 / 78) in pattern (6 / 9), elapsed time: 666.55
# Number of point sources considered (71 / 78) in pattern (6 / 9), elapsed time: 667.91
# Number of point sources considered (72 / 78) in pattern (6 / 9), elapsed time: 669.29
# Number of point sources considered (73 / 78) in pattern (6 / 9), elapsed time: 670.65
# Number of point sources considered (74 / 78) in pattern (6 / 9), elapsed time: 672.02
# Number of point sources considered (75 / 78) in pattern (6 / 9), elapsed time: 673.38
# Number of point sources considered (76 / 78) in pattern (6 / 9), elapsed time: 674.76
# Number of point sources considered (77 / 78) in pattern (6 / 9), elapsed time: 676.12
# Number of point sources considered (78 / 78) in pattern (6 / 9), elapsed time: 677.49
# Number of point sources considered (1 / 85) in pattern (7 / 9), elapsed time: 679.07
# Number of point sources considered (2 / 85) in pattern (7 / 9), elapsed time: 680.44
# Number of point sources considered (3 / 85) in pattern (7 / 9), elapsed time: 681.81
# Number of point sources considered (4 / 85) in pattern (7 / 9), elapsed time: 683.18
# Number of point sources considered (5 / 85) in pattern (7 / 9), elapsed time: 684.54
# Number of point sources considered (6 / 85) in pattern (7 / 9), elapsed time: 685.91
# Number of point sources considered (7 / 85) in pattern (7 / 9), elapsed time: 687.27
# Number of point sources considered (8 / 85) in pattern (7 / 9), elapsed time: 688.63
# Number of point sources considered (9 / 85) in pattern (7 / 9), elapsed time: 690.00
# Number of point sources considered (10 / 85) in pattern (7 / 9), elapsed time: 691.37
# Number of point sources considered (11 / 85) in pattern (7 / 9), elapsed time: 692.73
# Number of point sources considered (12 / 85) in pattern (7 / 9), elapsed time: 694.10
# Number of point sources considered (13 / 85) in pattern (7 / 9), elapsed time: 695.47
# Number of point sources considered (14 / 85) in pattern (7 / 9), elapsed time: 696.83
# Number of point sources considered (15 / 85) in pattern (7 / 9), elapsed time: 698.19
# Number of point sources considered (16 / 85) in pattern (7 / 9), elapsed time: 699.56
# Number of point sources considered (17 / 85) in pattern (7 / 9), elapsed time: 700.92
# Number of point sources considered (18 / 85) in pattern (7 / 9), elapsed time: 702.29
# Number of point sources considered (19 / 85) in pattern (7 / 9), elapsed time: 703.65
# Number of point sources considered (20 / 85) in pattern (7 / 9), elapsed time: 705.01
# Number of point sources considered (21 / 85) in pattern (7 / 9), elapsed time: 706.37
# Number of point sources considered (22 / 85) in pattern (7 / 9), elapsed time: 707.74
# Number of point sources considered (23 / 85) in pattern (7 / 9), elapsed time: 709.10
# Number of point sources considered (24 / 85) in pattern (7 / 9), elapsed time: 710.47
# Number of point sources considered (25 / 85) in pattern (7 / 9), elapsed time: 711.84
# Number of point sources considered (26 / 85) in pattern (7 / 9), elapsed time: 713.20
# Number of point sources considered (27 / 85) in pattern (7 / 9), elapsed time: 714.57
# Number of point sources considered (28 / 85) in pattern (7 / 9), elapsed time: 715.93
# Number of point sources considered (29 / 85) in pattern (7 / 9), elapsed time: 717.29
# Number of point sources considered (30 / 85) in pattern (7 / 9), elapsed time: 718.66
# Number of point sources considered (31 / 85) in pattern (7 / 9), elapsed time: 720.02
# Number of point sources considered (32 / 85) in pattern (7 / 9), elapsed time: 721.39
# Number of point sources considered (33 / 85) in pattern (7 / 9), elapsed time: 722.75
# Number of point sources considered (34 / 85) in pattern (7 / 9), elapsed time: 724.12
# Number of point sources considered (35 / 85) in pattern (7 / 9), elapsed time: 725.48
# Number of point sources considered (36 / 85) in pattern (7 / 9), elapsed time: 726.84
# Number of point sources considered (37 / 85) in pattern (7 / 9), elapsed time: 728.20
# Number of point sources considered (38 / 85) in pattern (7 / 9), elapsed time: 729.57
# Number of point sources considered (39 / 85) in pattern (7 / 9), elapsed time: 730.94
# Number of point sources considered (40 / 85) in pattern (7 / 9), elapsed time: 732.30
# Number of point sources considered (41 / 85) in pattern (7 / 9), elapsed time: 733.66
# Number of point sources considered (42 / 85) in pattern (7 / 9), elapsed time: 735.03
# Number of point sources considered (43 / 85) in pattern (7 / 9), elapsed time: 736.39
# Number of point sources considered (44 / 85) in pattern (7 / 9), elapsed time: 737.75
# Number of point sources considered (45 / 85) in pattern (7 / 9), elapsed time: 739.11
# Number of point sources considered (46 / 85) in pattern (7 / 9), elapsed time: 740.48
# Number of point sources considered (47 / 85) in pattern (7 / 9), elapsed time: 741.85
# Number of point sources considered (48 / 85) in pattern (7 / 9), elapsed time: 743.21
# Number of point sources considered (49 / 85) in pattern (7 / 9), elapsed time: 744.57
# Number of point sources considered (50 / 85) in pattern (7 / 9), elapsed time: 745.94
# Number of point sources considered (51 / 85) in pattern (7 / 9), elapsed time: 747.30
# Number of point sources considered (52 / 85) in pattern (7 / 9), elapsed time: 748.66
# Number of point sources considered (53 / 85) in pattern (7 / 9), elapsed time: 750.03
# Number of point sources considered (54 / 85) in pattern (7 / 9), elapsed time: 751.39
# Number of point sources considered (55 / 85) in pattern (7 / 9), elapsed time: 752.75
# Number of point sources considered (56 / 85) in pattern (7 / 9), elapsed time: 754.11
# Number of point sources considered (57 / 85) in pattern (7 / 9), elapsed time: 755.47
# Number of point sources considered (58 / 85) in pattern (7 / 9), elapsed time: 756.84
# Number of point sources considered (59 / 85) in pattern (7 / 9), elapsed time: 758.20
# Number of point sources considered (60 / 85) in pattern (7 / 9), elapsed time: 759.56
# Number of point sources considered (61 / 85) in pattern (7 / 9), elapsed time: 760.92
# Number of point sources considered (62 / 85) in pattern (7 / 9), elapsed time: 762.31
# Number of point sources considered (63 / 85) in pattern (7 / 9), elapsed time: 763.67
# Number of point sources considered (64 / 85) in pattern (7 / 9), elapsed time: 765.03
# Number of point sources considered (65 / 85) in pattern (7 / 9), elapsed time: 766.39
# Number of point sources considered (66 / 85) in pattern (7 / 9), elapsed time: 767.75
# Number of point sources considered (67 / 85) in pattern (7 / 9), elapsed time: 769.12
# Number of point sources considered (68 / 85) in pattern (7 / 9), elapsed time: 770.49
# Number of point sources considered (69 / 85) in pattern (7 / 9), elapsed time: 771.86
# Number of point sources considered (70 / 85) in pattern (7 / 9), elapsed time: 773.22
# ...
# Number of point sources considered (57 / 78) in pattern (8 / 9), elapsed time: 871.75
# Number of point sources considered (58 / 78) in pattern (8 / 9), elapsed time: 873.12
# Number of point sources considered (59 / 78) in pattern (8 / 9), elapsed time: 874.48
# Number of point sources considered (60 / 78) in pattern (8 / 9), elapsed time: 875.84
# Number of point sources considered (61 / 78) in pattern (8 / 9), elapsed time: 877.20
# Number of point sources considered (62 / 78) in pattern (8 / 9), elapsed time: 878.57
# Number of point sources considered (63 / 78) in pattern (8 / 9), elapsed time: 879.93
# Number of point sources considered (64 / 78) in pattern (8 / 9), elapsed time: 881.30
# Number of point sources considered (65 / 78) in pattern (8 / 9), elapsed time: 882.66
# Number of point sources considered (66 / 78) in pattern (8 / 9), elapsed time: 884.02
# Number of point sources considered (67 / 78) in pattern (8 / 9), elapsed time: 885.38
# Number of point sources considered (68 / 78) in pattern (8 / 9), elapsed time: 886.75
# Number of point sources considered (69 / 78) in pattern (8 / 9), elapsed time: 888.11
# Number of point sources considered (70 / 78) in pattern (8 / 9), elapsed time: 889.47
# Number of point sources considered (71 / 78) in pattern (8 / 9), elapsed time: 890.85
# Number of point sources considered (72 / 78) in pattern (8 / 9), elapsed time: 892.21
# Number of point sources considered (73 / 78) in pattern (8 / 9), elapsed time: 893.58
# Number of point sources considered (74 / 78) in pattern (8 / 9), elapsed time: 894.94
# Number of point sources considered (75 / 78) in pattern (8 / 9), elapsed time: 896.31
# Number of point sources considered (76 / 78) in pattern (8 / 9), elapsed time: 897.67
# Number of point sources considered (77 / 78) in pattern (8 / 9), elapsed time: 899.03
# Number of point sources considered (78 / 78) in pattern (8 / 9), elapsed time: 900.40
# Number of point sources considered (1 / 160) in pattern (9 / 9), elapsed time: 901.98
# Number of point sources considered (2 / 160) in pattern (9 / 9), elapsed time: 903.35
# Number of point sources considered (3 / 160) in pattern (9 / 9), elapsed time: 904.71
# Number of point sources considered (4 / 160) in pattern (9 / 9), elapsed time: 906.08
# Number of point sources considered (5 / 160) in pattern (9 / 9), elapsed time: 907.44
# Number of point sources considered (6 / 160) in pattern (9 / 9), elapsed time: 908.81
# Number of point sources considered (7 / 160) in pattern (9 / 9), elapsed time: 910.18
# Number of point sources considered (8 / 160) in pattern (9 / 9), elapsed time: 911.55
# Number of point sources considered (9 / 160) in pattern (9 / 9), elapsed time: 912.92
# Number of point sources considered (10 / 160) in pattern (9 / 9), elapsed time: 914.28
# Number of point sources considered (11 / 160) in pattern (9 / 9), elapsed time: 915.64
# Number of point sources considered (12 / 160) in pattern (9 / 9), elapsed time: 917.00
# Number of point sources considered (13 / 160) in pattern (9 / 9), elapsed time: 918.37
# Number of point sources considered (14 / 160) in pattern (9 / 9), elapsed time: 919.73
# Number of point sources considered (15 / 160) in pattern (9 / 9), elapsed time: 921.10
# Number of point sources considered (16 / 160) in pattern (9 / 9), elapsed time: 922.46
# Number of point sources considered (17 / 160) in pattern (9 / 9), elapsed time: 923.83
# Number of point sources considered (18 / 160) in pattern (9 / 9), elapsed time: 925.19
# Number of point sources considered (19 / 160) in pattern (9 / 9), elapsed time: 926.56
# Number of point sources considered (20 / 160) in pattern (9 / 9), elapsed time: 927.92
# Number of point sources considered (21 / 160) in pattern (9 / 9), elapsed time: 929.29
# Number of point sources considered (22 / 160) in pattern (9 / 9), elapsed time: 930.65
# Number of point sources considered (23 / 160) in pattern (9 / 9), elapsed time: 932.01
# Number of point sources considered (24 / 160) in pattern (9 / 9), elapsed time: 933.37
# Number of point sources considered (25 / 160) in pattern (9 / 9), elapsed time: 934.74
# Number of point sources considered (26 / 160) in pattern (9 / 9), elapsed time: 936.11
# Number of point sources considered (27 / 160) in pattern (9 / 9), elapsed time: 937.47
# Number of point sources considered (28 / 160) in pattern (9 / 9), elapsed time: 938.84
# Number of point sources considered (29 / 160) in pattern (9 / 9), elapsed time: 940.20
# Number of point sources considered (30 / 160) in pattern (9 / 9), elapsed time: 941.56
# Number of point sources considered (31 / 160) in pattern (9 / 9), elapsed time: 942.93
# Number of point sources considered (32 / 160) in pattern (9 / 9), elapsed time: 944.29
# Number of point sources considered (33 / 160) in pattern (9 / 9), elapsed time: 945.65
# Number of point sources considered (34 / 160) in pattern (9 / 9), elapsed time: 947.02
# Number of point sources considered (35 / 160) in pattern (9 / 9), elapsed time: 948.38
# Number of point sources considered (36 / 160) in pattern (9 / 9), elapsed time: 949.76
# Number of point sources considered (37 / 160) in pattern (9 / 9), elapsed time: 951.13
# Number of point sources considered (38 / 160) in pattern (9 / 9), elapsed time: 952.50
# Number of point sources considered (39 / 160) in pattern (9 / 9), elapsed time: 953.87
# Number of point sources considered (40 / 160) in pattern (9 / 9), elapsed time: 955.23
# Number of point sources considered (41 / 160) in pattern (9 / 9), elapsed time: 956.60
# Number of point sources considered (42 / 160) in pattern (9 / 9), elapsed time: 957.96
# Number of point sources considered (43 / 160) in pattern (9 / 9), elapsed time: 959.33
# Number of point sources considered (44 / 160) in pattern (9 / 9), elapsed time: 960.69
# Number of point sources considered (45 / 160) in pattern (9 / 9), elapsed time: 962.07
# Number of point sources considered (46 / 160) in pattern (9 / 9), elapsed time: 963.43
# Number of point sources considered (47 / 160) in pattern (9 / 9), elapsed time: 964.80
# Number of point sources considered (48 / 160) in pattern (9 / 9), elapsed time: 966.17
# Number of point sources considered (49 / 160) in pattern (9 / 9), elapsed time: 967.53
# Number of point sources considered (50 / 160) in pattern (9 / 9), elapsed time: 968.89
# Number of point sources considered (51 / 160) in pattern (9 / 9), elapsed time: 970.26
# Number of point sources considered (52 / 160) in pattern (9 / 9), elapsed time: 971.62
# Number of point sources considered (53 / 160) in pattern (9 / 9), elapsed time: 972.99
# Number of point sources considered (54 / 160) in pattern (9 / 9), elapsed time: 974.36
# Number of point sources considered (55 / 160) in pattern (9 / 9), elapsed time: 975.73
# Number of point sources considered (56 / 160) in pattern (9 / 9), elapsed time: 977.09
# Number of point sources considered (57 / 160) in pattern (9 / 9), elapsed time: 978.46
# Number of point sources considered (58 / 160) in pattern (9 / 9), elapsed time: 979.83
# Number of point sources considered (59 / 160) in pattern (9 / 9), elapsed time: 981.20
# Number of point sources considered (60 / 160) in pattern (9 / 9), elapsed time: 982.57
# Number of point sources considered (61 / 160) in pattern (9 / 9), elapsed time: 983.94
# Number of point sources considered (62 / 160) in pattern (9 / 9), elapsed time: 985.31
# Number of point sources considered (63 / 160) in pattern (9 / 9), elapsed time: 986.67
# Number of point sources considered (64 / 160) in pattern (9 / 9), elapsed time: 988.04
# Number of point sources considered (65 / 160) in pattern (9 / 9), elapsed time: 989.41
# Number of point sources considered (66 / 160) in pattern (9 / 9), elapsed time: 990.78
# Number of point sources considered (67 / 160) in pattern (9 / 9), elapsed time: 992.14
# Number of point sources considered (68 / 160) in pattern (9 / 9), elapsed time: 993.51
# Number of point sources considered (69 / 160) in pattern (9 / 9), elapsed time: 994.88
# Number of point sources considered (70 / 160) in pattern (9 / 9), elapsed time: 996.25
# Number of point sources considered (71 / 160) in pattern (9 / 9), elapsed time: 997.61
# Number of point sources considered (72 / 160) in pattern (9 / 9), elapsed time: 998.98
# Number of point sources considered (73 / 160) in pattern (9 / 9), elapsed time: 1000.35
# Number of point sources considered (74 / 160) in pattern (9 / 9), elapsed time: 1001.71
# Number of point sources considered (75 / 160) in pattern (9 / 9), elapsed time: 1003.07
# Number of point sources considered (76 / 160) in pattern (9 / 9), elapsed time: 1004.44
# Number of point sources considered (77 / 160) in pattern (9 / 9), elapsed time: 1005.81
# Number of point sources considered (78 / 160) in pattern (9 / 9), elapsed time: 1007.17
# Number of point sources considered (79 / 160) in pattern (9 / 9), elapsed time: 1008.54
# Number of point sources considered (80 / 160) in pattern (9 / 9), elapsed time: 1009.91
# Number of point sources considered (81 / 160) in pattern (9 / 9), elapsed time: 1011.28
# Number of point sources considered (82 / 160) in pattern (9 / 9), elapsed time: 1012.65
# Number of point sources considered (83 / 160) in pattern (9 / 9), elapsed time: 1014.01
# Number of point sources considered (84 / 160) in pattern (9 / 9), elapsed time: 1015.40
# Number of point sources considered (85 / 160) in pattern (9 / 9), elapsed time: 1016.76
# Number of point sources considered (86 / 160) in pattern (9 / 9), elapsed time: 1018.13
# Number of point sources considered (87 / 160) in pattern (9 / 9), elapsed time: 1019.49
# Number of point sources considered (88 / 160) in pattern (9 / 9), elapsed time: 1020.86
# Number of point sources considered (89 / 160) in pattern (9 / 9), elapsed time: 1022.23
# Number of point sources considered (90 / 160) in pattern (9 / 9), elapsed time: 1023.60
# Number of point sources considered (91 / 160) in pattern (9 / 9), elapsed time: 1024.97
# Number of point sources considered (92 / 160) in pattern (9 / 9), elapsed time: 1026.34
# Number of point sources considered (93 / 160) in pattern (9 / 9), elapsed time: 1027.71
# Number of point sources considered (94 / 160) in pattern (9 / 9), elapsed time: 1029.07
# Number of point sources considered (95 / 160) in pattern (9 / 9), elapsed time: 1030.43
# Number of point sources considered (96 / 160) in pattern (9 / 9), elapsed time: 1031.80
# Number of point sources considered (97 / 160) in pattern (9 / 9), elapsed time: 1033.16
# Number of point sources considered (98 / 160) in pattern (9 / 9), elapsed time: 1034.52
# Number of point sources considered (99 / 160) in pattern (9 / 9), elapsed time: 1035.89
# Number of point sources considered (100 / 160) in pattern (9 / 9), elapsed time: 1037.25
# Number of point sources considered (101 / 160) in pattern (9 / 9), elapsed time: 1038.61
# Number of point sources considered (102 / 160) in pattern (9 / 9), elapsed time: 1039.98
# Number of point sources considered (103 / 160) in pattern (9 / 9), elapsed time: 1041.35
# Number of point sources considered (104 / 160) in pattern (9 / 9), elapsed time: 1042.72
# Number of point sources considered (105 / 160) in pattern (9 / 9), elapsed time: 1044.08
# Number of point sources considered (106 / 160) in pattern (9 / 9), elapsed time: 1045.45
# Number of point sources considered (107 / 160) in pattern (9 / 9), elapsed time: 1046.82
# Number of point sources considered (108 / 160) in pattern (9 / 9), elapsed time: 1048.19
# Number of point sources considered (109 / 160) in pattern (9 / 9), elapsed time: 1049.55
# Number of point sources considered (110 / 160) in pattern (9 / 9), elapsed time: 1050.91
# Number of point sources considered (111 / 160) in pattern (9 / 9), elapsed time: 1052.28
# Number of point sources considered (112 / 160) in pattern (9 / 9), elapsed time: 1053.64
# Number of point sources considered (113 / 160) in pattern (9 / 9), elapsed time: 1055.00
# Number of point sources considered (114 / 160) in pattern (9 / 9), elapsed time: 1056.39
# Number of point sources considered (115 / 160) in pattern (9 / 9), elapsed time: 1057.76
# Number of point sources considered (116 / 160) in pattern (9 / 9), elapsed time: 1059.12
# Number of point sources considered (117 / 160) in pattern (9 / 9), elapsed time: 1060.48
# Number of point sources considered (118 / 160) in pattern (9 / 9), elapsed time: 1061.85
# Number of point sources considered (119 / 160) in pattern (9 / 9), elapsed time: 1063.22
# Number of point sources considered (120 / 160) in pattern (9 / 9), elapsed time: 1064.58
# Number of point sources considered (121 / 160) in pattern (9 / 9), elapsed time: 1065.94
# Number of point sources considered (122 / 160) in pattern (9 / 9), elapsed time: 1067.31
# Number of point sources considered (123 / 160) in pattern (9 / 9), elapsed time: 1068.67
# Number of point sources considered (124 / 160) in pattern (9 / 9), elapsed time: 1070.04
# Number of point sources considered (125 / 160) in pattern (9 / 9), elapsed time: 1071.41
# Number of point sources considered (126 / 160) in pattern (9 / 9), elapsed time: 1072.77
# Number of point sources considered (127 / 160) in pattern (9 / 9), elapsed time: 1074.14
# Number of point sources considered (128 / 160) in pattern (9 / 9), elapsed time: 1075.51
# Number of point sources considered (129 / 160) in pattern (9 / 9), elapsed time: 1076.88
# Number of point sources considered (130 / 160) in pattern (9 / 9), elapsed time: 1078.25
# Number of point sources considered (131 / 160) in pattern (9 / 9), elapsed time: 1079.61
# Number of point sources considered (132 / 160) in pattern (9 / 9), elapsed time: 1080.97
# Number of point sources considered (133 / 160) in pattern (9 / 9), elapsed time: 1082.34
# Number of point sources considered (134 / 160) in pattern (9 / 9), elapsed time: 1083.70
# Number of point sources considered (135 / 160) in pattern (9 / 9), elapsed time: 1085.06
# Number of point sources considered (136 / 160) in pattern (9 / 9), elapsed time: 1086.44
# Number of point sources considered (137 / 160) in pattern (9 / 9), elapsed time: 1087.81
# Number of point sources considered (138 / 160) in pattern (9 / 9), elapsed time: 1089.17
# Number of point sources considered (139 / 160) in pattern (9 / 9), elapsed time: 1090.54
# Number of point sources considered (140 / 160) in pattern (9 / 9), elapsed time: 1091.91
# Number of point sources considered (141 / 160) in pattern (9 / 9), elapsed time: 1093.27
# Number of point sources considered (142 / 160) in pattern (9 / 9), elapsed time: 1094.64
# Number of point sources considered (143 / 160) in pattern (9 / 9), elapsed time: 1096.00
# Number of point sources considered (144 / 160) in pattern (9 / 9), elapsed time: 1097.37
# Number of point sources considered (145 / 160) in pattern (9 / 9), elapsed time: 1098.74
# Number of point sources considered (146 / 160) in pattern (9 / 9), elapsed time: 1100.10
# Number of point sources considered (147 / 160) in pattern (9 / 9), elapsed time: 1101.47
# Number of point sources considered (148 / 160) in pattern (9 / 9), elapsed time: 1102.84
# Number of point sources considered (149 / 160) in pattern (9 / 9), elapsed time: 1104.20
# Number of point sources considered (150 / 160) in pattern (9 / 9), elapsed time: 1105.57
# Number of point sources considered (151 / 160) in pattern (9 / 9), elapsed time: 1106.93
# Number of point sources considered (152 / 160) in pattern (9 / 9), elapsed time: 1108.30
# Number of point sources considered (153 / 160) in pattern (9 / 9), elapsed time: 1109.66
# Number of point sources considered (154 / 160) in pattern (9 / 9), elapsed time: 1111.03
# Number of point sources considered (155 / 160) in pattern (9 / 9), elapsed time: 1112.39
# Number of point sources considered (156 / 160) in pattern (9 / 9), elapsed time: 1113.76
# Number of point sources considered (157 / 160) in pattern (9 / 9), elapsed time: 1115.12
# Number of point sources considered (158 / 160) in pattern (9 / 9), elapsed time: 1116.50
# Number of point sources considered (159 / 160) in pattern (9 / 9), elapsed time: 1117.87
# Number of point sources considered (160 / 160) in pattern (9 / 9), elapsed time: 1119.23

# %%
# animate through the simulated Stokes parameters (stack_idx_1: z, stack_idx_2: illumination pattern)
wo.parallel_5D_viewer(np.transpose(Stokes_SEAGLE,(4,1,0,2,3)), num_col=4, size=5, origin='lower', \
                      set_title=True, titles=[r'$S_0$', r'$S_1$', r'$S_2$', r'$S_3$'])
# Out:
# interactive(children=(IntSlider(value=0, description='stack_idx_1', max=99), IntSlider(value=0, description='s…
# <function waveorder.visual.parallel_5D_viewer.<locals>.interact_plot(stack_idx_1, stack_idx_2)>

# %%
# animate through the simulated measured intensity (stack_idx_1: z, stack_idx_2: illumination pattern)
wo.parallel_5D_viewer(np.transpose(I_meas_SEAGLE,(4,1,0,2,3)), num_col=5, size=5, origin='lower', \
                      set_title=True, titles=[r'$I_{ext}$',r'$I_{0}$',r'$I_{45}$',r'$I_{90}$', r'$I_{135}$'])
# Out:
# interactive(children=(IntSlider(value=0, description='stack_idx_1', max=99), IntSlider(value=0, description='s…
# <function waveorder.visual.parallel_5D_viewer.<locals>.interact_plot(stack_idx_1, stack_idx_2)>

# %%
## situation with no noise ##
photon_count = 5000
I_meas_noise = I_meas_SEAGLE/np.mean(I_meas_SEAGLE) * photon_count
#############################


# # Add noise to the measurement ##
# photon_count = 50000
# ext_ratio    = 1000
# const_bg     = photon_count/(0.5*(1-np.cos(chi)))/ext_ratio
# I_meas_noise = (np.random.poisson(I_meas_SEAGLE/np.mean(I_meas_SEAGLE) * photon_count + const_bg)).astype('float64')
# #################################

# %%
# animate through the simulated measured intensity (stack_idx_1: z, stack_idx_2: illumination pattern)
wo.parallel_5D_viewer(np.transpose(I_meas_noise,(4,1,0,2,3)), num_col=5, size=5, origin='lower', \
                      set_title=True, titles=[r'$I_{ext}$',r'$I_{0}$',r'$I_{45}$',r'$I_{90}$', r'$I_{135}$'])
# Out:
# interactive(children=(IntSlider(value=0, description='stack_idx_1', max=99), IntSlider(value=0, description='s…
# <function waveorder.visual.parallel_5D_viewer.<locals>.interact_plot(stack_idx_1, stack_idx_2)>

# %% [markdown]
# #### Save simulation

# %%
# Save simulations

if sample_type == '3D':
    output_file = 'uPTI_simulation_data_NA_det_147_NA_illu_140_3D_spoke_discrete_no_1528_ne_1553_no_noise_Born'
elif sample_type == '2D':
    output_file = 'uPTI_simulation_data_NA_det_147_NA_illu_140_2D_spoke_discrete_no_1528_ne_1553_no_noise_Born'
else:
    print('sample_type needs to be 2D or 3D.')

np.savez(output_file, I_meas=I_meas_noise, lambda_illu=lambda_illu, n_media=n_media, NA_obj=NA_obj, NA_illu=NA_illu,\
                      ps=ps, psz=psz, Source_cont=Source_cont, Source_PolState=Source_PolState, \
                      z_defocus=z_defocus, chi=chi)

# %%
import cupy as cp
import gc
gc.collect()
cp.get_default_memory_pool().free_all_blocks()
