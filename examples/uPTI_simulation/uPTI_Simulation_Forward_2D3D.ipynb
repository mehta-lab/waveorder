# %% [markdown]
# # Forward simulation of uniaxial permittivity tensor imaging (uPTI)
# This simulation is based on the uPTI paper [here](https://www.biorxiv.org/content/10.1101/2020.12.15.422951v1): <br>
# ``` L.-H. Yeh, I. E. Ivanov, B. B. Chhun, S.-M. Guo, E. Hashemi, J. R. Byrum, J. A. Pérez-Bermejo, H. Wang, Y. Yu, P. G. Kazansky, B. R. Conklin, M. H. Han, and S. B. Mehta, "uPTI: uniaxial permittivity tensor imaging of intrinsic density and anisotropy," bioRxiv 2020.12.15.422951 (2020).```

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.fft import fft, ifft, fft2, ifft2, fftshift, ifftshift, fftn, ifftn

import pickle
import waveorder as wo
import time



# %matplotlib inline

# %% [markdown]
# ## Initialization - imaging system and sample

# %% [markdown]
# ### Assumptions

# %% [markdown]
# *  In our simulations, the specimen is always assumed to be 3D in order to model volumetric scattering.
# * A 2D specimen, i.e., a specimen thinner than the depth of focus of the microscope, is simulated by setting a single layer of the volume to sample properties.
# For a 2D specimen, all layers other than sample layer are assumed to have the isotropic permittivity of the surrounding medium.
# * This forward simulation generates 3D intensity stacks acquired with 9 patterns of asymmetric illumination and 4 polarization states for both a 2D thin specimen or a 3D specimen.
# * 3D reconstruction notebook can be used to reconstruct the 3D uPT of the 2D or 3D specimen given their intensity stacks.
# The 3D reconstruction of 2D specimen will report isotropic permittivity of medium outside of the depth of focus of the microscope.
# * 2D reconstruction notebook computes 2D uPT from a slice of the intensity stacks and it only works for the 2D thin specimen.

# %% [markdown]
# ### Parameters of sample

# %%
sample_type = '2D'               # 2D or 3D
N           = 200                 # number of pixel in y dimension
M           = 200                 # number of pixel in x dimension
L           = 100                 # number of layers in z dimension
z_layer     = 50                  # default z-slice to display in XY views.
y_layer     = 100                 # default y-slice to display in XZ views.

# %% [markdown]
# ### Parameters of imaging system

# %%
n_media     = 1.518               # refractive index in the media
mag         = 63                  # magnification
ps          = 6/mag               # effective pixel size
psz         = 0.125/2             # axial pixel size
lambda_illu = 0.532               # wavelength
NA_obj      = 1.47                # objective NA
NA_illu     = 1.4                 # illumination NA
chi         = 0.25*2*np.pi        # swing of the microscope
z_defocus = (np.r_[:L]-L//2)*psz  # defocus position
use_gpu     = True                # option to use gpu
gpu_id      = 0                   # gpu to be used

# %% [markdown]
# ### Sample pattern

# %%
if sample_type == '3D':
    # 3D spoke pattern whose spokes are inclined 60 degrees relative to the z-axis. The principal retardance varies with depth and 3D orientation of permittivity tensor is aligned with the structural orientation of the spoke.
    blur_size = 1*ps
    target, azimuth, inclination = wo.genStarTarget_3D((N,M,L), ps, psz, blur_size, inc_upper_bound=np.pi/8, inc_range=np.pi/64)
    inclination = np.round(inclination/np.pi*8)/8*np.pi
    azimuth   = np.round(azimuth/np.pi/2*16)/16*np.pi*2
elif sample_type == '2D':
    ## 2D spoke pattern, azimuth aligned with spokes, and the inclination set to 60 degrees ##
    target, azimuth, _ = wo.genStarTarget(N,M, blur_px=1*ps, margin=60)
    inclination = np.ones_like(target)*np.pi/3
    azimuth   = azimuth%(np.pi*2)
    azimuth   = np.round(azimuth/np.pi/2*16)/16*np.pi*2
    
    # pad zero in the z direction outside of the focal plane to mimic thin specimens
    target = np.pad(target[:,:,np.newaxis], ((0,0), (0,0), (50,49)), mode='constant')
    azimuth = np.pad(azimuth[:,:,np.newaxis], ((0,0), (0,0), (50,49)), mode='constant')
    inclination = np.pad(inclination[:,:,np.newaxis], ((0,0), (0,0), (50,49)), mode='constant')
else:
    print('sample_type needs to be 2D or 3D.')

# %%
# principal retardance, radial azimuth, and constant inclination to the pattern

n_o = n_media+0.01 
n_e = n_media+0.035

inclination = inclination
azimuth = (azimuth)%(2*np.pi)


no_map = np.zeros((N,M,L))
no_map[target > 0] = target[target > 0]*(n_o-n_media)
no_map += n_media
no_map_copy = no_map.copy()

ne_map = np.zeros((N,M,L))
ne_map[target > 0] = target[target > 0]*(n_e-n_media)
ne_map += n_media
ne_map_copy = ne_map.copy()

biref_map = ne_map_copy -  no_map_copy
## assign material on the top to be reverse optic sign ##
# no_map[:,:,L//2:] = ne_map_copy[:,:,L//2:].copy()
# ne_map[:,:,L//2:] = no_map_copy[:,:,L//2:].copy()
#########################################################

## assign material on the right to be reverse optic sign ##
# no_map[:,M//2:,:] = ne_map_copy[:,M//2:,:].copy()
# ne_map[:,M//2:,:] = no_map_copy[:,M//2:,:].copy()
###########################################################

# %% [markdown]
# ### Visualize sample properties

# %% [markdown]
# #### XY sections

# %%
wo.plot_multicolumn([target[:,:,z_layer], azimuth[:,:,z_layer]%(2*np.pi), inclination[:,:,z_layer]], origin='lower', size=5, num_col=3, titles=[f'target, z={z_layer}', 'azimuth', 'inclination'], set_title = True)
    
## animate through z-slices with this function ##
wo.parallel_4D_viewer(np.transpose(np.stack([biref_map, azimuth, inclination]),(3,0,1,2)), num_col=3, size=5, origin='lower',\
                     set_title=True, titles=[r'retardance',r'azimuth',r'inclination'])
#################################################
# Out:
# interactive(children=(IntSlider(value=0, description='stack_idx', max=99), Output()), _dom_classes=('widget-in…
# <function waveorder.visual.parallel_4D_viewer.<locals>.interact_plot(stack_idx)>

# %% [markdown]
# #### XZ sections

# %%
## xz section at y_layer ##
wo.plot_multicolumn([np.transpose(target[y_layer,:,:]), np.transpose(azimuth[y_layer,:,:])%(2*np.pi), np.transpose(inclination[y_layer,:,:])], origin='lower', size=5, num_col=3, titles=['retardance', 'azimuth', 'inclination'], set_title = True)
wo.parallel_4D_viewer(np.transpose(np.stack([target, azimuth%(2*np.pi), inclination]),(2,0,3,1)), num_col=3, size=5, origin='lower',\
                     set_title=True, titles=[r'retardance',r'azimuth',r'inclination'])
# Out:
# interactive(children=(IntSlider(value=0, description='stack_idx', max=199), Output()), _dom_classes=('widget-i…
# <function waveorder.visual.parallel_4D_viewer.<locals>.interact_plot(stack_idx)>

# %% [markdown]
# #### Principal retardance and 3D orientation in color

# %%
orientation_3D_image = np.transpose(np.array([azimuth%(2*np.pi)/2/np.pi, inclination,  np.clip((ne_map-no_map)*psz*2*np.pi/lambda_illu/np.pi/2*lambda_illu*1e3,0, 1.5)/1.5]),(3,1,2,0))
orientation_3D_image_RGB = wo.orientation_3D_to_rgb(orientation_3D_image, interp_belt = 20/180*np.pi, sat_factor = 1)

plt.figure(figsize=(10,10))
plt.imshow(orientation_3D_image_RGB[z_layer], origin='lower')
# wo.rgb_stack_viewer(orientation_3D_image_RGB, size=10, origin='lower')
plt.figure(figsize=(3,3))
wo.orientation_3D_colorwheel(wheelsize=128, circ_size=50, interp_belt=20/180*np.pi, sat_factor=1, discretize=True)


plt.figure(figsize=(10,10))
plt.imshow(orientation_3D_image_RGB[:,y_layer], origin='lower')
#wo.rgb_stack_viewer(np.transpose(orientation_3D_image_RGB,(1,0,2,3)), size=10, origin='lower')
plt.figure(figsize=(3,3))
wo.orientation_3D_colorwheel(wheelsize=128, circ_size=50, interp_belt=20/180*np.pi, sat_factor=1,  discretize=True)

# %% [markdown]
# #### Angular histogram of 3D orientation

# %%
wo.orientation_3D_hist(azimuth.flatten(), \
                       inclination.flatten(), \
                       np.abs(target).flatten(),\
                       bins=36, num_col=1, size=10, contour_level = 100, hist_cmap='gnuplot2', top_hemi=True)
# Out:
# (<Figure size 720x720 with 2 Axes>, <PolarAxesSubplot:>)

# %% [markdown]
# ## Compute permittivity and scattering potential tensors

# %% [markdown]
# ### assign the permittivity tensor according to the sample properties

# %%
epsilon_mean = (ne_map**2 + no_map**2)/2
epsilon_del = (ne_map**2 - no_map**2)/2

epsilon_tensor = np.zeros((3,3,N,M,L))
epsilon_tensor[0,0] = epsilon_mean - epsilon_del*(np.cos(inclination)**2 - np.sin(inclination)**2 * np.cos(2*azimuth))
epsilon_tensor[0,1] = epsilon_del * np.sin(inclination)**2 * np.sin(2*azimuth)
epsilon_tensor[0,2] = epsilon_del * np.sin(2*inclination) * np.cos(azimuth)

epsilon_tensor[1,0] = epsilon_del * np.sin(inclination)**2 * np.sin(2*azimuth)
epsilon_tensor[1,1] = epsilon_mean - epsilon_del*(np.cos(inclination)**2 + np.sin(inclination)**2 * np.cos(2*azimuth))
epsilon_tensor[1,2] = epsilon_del * np.sin(2*inclination) * np.sin(azimuth)

epsilon_tensor[2,0] = epsilon_del * np.sin(2*inclination) * np.cos(azimuth)
epsilon_tensor[2,1] = epsilon_del * np.sin(2*inclination) * np.sin(azimuth)
epsilon_tensor[2,2] = epsilon_mean + epsilon_del*np.cos(2*inclination)


wo.plot_multicolumn([epsilon_tensor[0,0,:,:,z_layer], epsilon_tensor[0,1,:,:,z_layer], epsilon_tensor[0,2,:,:,z_layer],\
                     epsilon_tensor[1,0,:,:,z_layer], epsilon_tensor[1,1,:,:,z_layer], epsilon_tensor[1,2,:,:,z_layer],\
                     epsilon_tensor[2,0,:,:,z_layer], epsilon_tensor[2,1,:,:,z_layer], epsilon_tensor[2,2,:,:,z_layer]], origin='lower', num_col=3, titles=[r'$\epsilon_{xx}$', r'$\epsilon_{xy}$',r'$\epsilon_{xz}$',\
                                                                                                                                                            r'$\epsilon_{yx}$', r'$\epsilon_{yy}$', r'$\epsilon_{yz}$',\
                                                                                                                                                            r'$\epsilon_{zx}$', r'$\epsilon_{zy}$', r'$\epsilon_{zz}$'],\
                                                                                                                                                            size=5, set_title = True)

# %%
## animate through z-slices with this function ##
wo.parallel_4D_viewer(np.transpose(epsilon_tensor.reshape((9, N, M, L)),(3,0,1,2)), num_col=3, size=5, origin='lower',\
                     set_title = True, titles=[r'$\epsilon_{xx}$', r'$\epsilon_{xy}$',r'$\epsilon_{xz}$',\
                                               r'$\epsilon_{yx}$', r'$\epsilon_{yy}$', r'$\epsilon_{yz}$',\
                                               r'$\epsilon_{zx}$', r'$\epsilon_{zy}$', r'$\epsilon_{zz}$'])
#################################################
# Out:
# interactive(children=(IntSlider(value=0, description='stack_idx', max=99), Output()), _dom_classes=('widget-in…
# <function waveorder.visual.parallel_4D_viewer.<locals>.interact_plot(stack_idx)>

# %% [markdown]
# ### Compute components of scattering potential tensor
# ($f_{0r}, f_{0i}, f_{1c}, f_{1s}, f_{2c},f_{2s}, f_{3}$)

# %%
# the corresponding components of the scattering potential tensor

del_f_component = np.zeros((7, N, M, L))
del_f_component[0] = np.real(((2*np.pi/lambda_illu)**2)*(n_media**2 -  epsilon_mean + epsilon_del*np.cos(inclination)**2))
del_f_component[1] = np.imag(((2*np.pi/lambda_illu)**2)*(n_media**2 -  epsilon_mean + epsilon_del*np.cos(inclination)**2))
del_f_component[2] = -((2*np.pi/lambda_illu)**2) * epsilon_del * np.sin(inclination)**2 * np.cos(2*azimuth)
del_f_component[3] = -((2*np.pi/lambda_illu)**2) * epsilon_del * np.sin(inclination)**2 * np.sin(2*azimuth)
del_f_component[4] = -((2*np.pi/lambda_illu)**2) * epsilon_del * np.sin(2*inclination) * np.cos(azimuth)
del_f_component[5] = -((2*np.pi/lambda_illu)**2) * epsilon_del * np.sin(2*inclination) * np.sin(azimuth)
del_f_component[6] = ((2*np.pi/lambda_illu)**2) * epsilon_del * (np.sin(inclination)**2 - 2*np.cos(inclination)**2)

# %%
wo.plot_multicolumn([del_f_component[0,:,:,z_layer], del_f_component[1,:,:,z_layer], del_f_component[2,:,:,z_layer], del_f_component[3,:,:,z_layer],\
                     del_f_component[4,:,:,z_layer], del_f_component[5,:,:,z_layer], del_f_component[6,:,:,z_layer]], origin='lower', num_col=4, titles=[r'$f_{0r}$', r'$f_{0i}$', r'$f_{1c}$',r'$f_{1s}$',\
                                                                                                                                                         r'$f_{2c}$', r'$f_{2s}$', r'$f_{3}$'],\
                                                                                                                                                         size=5, set_title = True)

# %%
## animate through z-slices with this function ##
wo.parallel_4D_viewer(np.transpose(del_f_component,(3,0,1,2)), num_col=4, size=5, origin='lower', \
                     set_title=True, titles=[r'$f_{0r}$', r'$f_{0i}$', r'$f_{1c}$',r'$f_{1s}$',\
                                             r'$f_{2c}$', r'$f_{2s}$', r'$f_{3}$'])
#################################################
# Out:
# interactive(children=(IntSlider(value=0, description='stack_idx', max=99), Output()), _dom_classes=('widget-in…
# <function waveorder.visual.parallel_4D_viewer.<locals>.interact_plot(stack_idx)>

# %% [markdown]
# ## Forward model of uPTI <br>(polarization-diverse, illumination-diverse, depth-diverse acquisition)

# %%
# DPC + BF illumination + PolState (sector illumination)

xx, yy, fxx, fyy = wo.gen_coordinate((N, M), ps)
Pupil_obj = wo.gen_Pupil(fxx, fyy, NA_obj/n_media, lambda_illu/n_media)
Source_support = wo.gen_Pupil(fxx, fyy, NA_illu/n_media, lambda_illu/n_media)

NAx_coord = lambda_illu/n_media*fxx
NAy_coord = lambda_illu/n_media*fyy


rotation_angle=[0, 45, 90, 135, 180, 225, 270, 315]


Source = np.zeros((len(rotation_angle)+1, N, M))
Source_cont = np.zeros_like(Source)

Source_BF = wo.gen_Pupil(fxx, fyy, NA_illu/n_media/2, lambda_illu/n_media)


Source_cont[-1] = Source_BF.copy()
Source[-1] = wo.Source_subsample(Source_BF, NAx_coord, NAy_coord, subsampled_NA = 0.1/n_media)



for i in range(len(rotation_angle)):
    deg = rotation_angle[i]
    Source_temp = np.zeros((N,M))
    Source_temp2 = np.zeros((N,M))
    Source_temp[fyy * np.cos(np.deg2rad(deg-22.5)) - fxx*np.sin(np.deg2rad(deg-22.5)) > 1e-10] = 1
    Source_temp2[fyy * np.cos(np.deg2rad(deg-135-22.5)) - fxx*np.sin(np.deg2rad(deg-135-22.5)) > 1e-10] = 1
    
    Source_cont[i] = Source_temp * Source_temp2 * Source_support 
    
    Source_discrete = wo.Source_subsample(Source_cont[i], NAx_coord, NAy_coord, subsampled_NA = 0.1/n_media)
    Source[i] = np.maximum(0,Source_discrete.copy())
    
    

Source_PolState = np.zeros((len(Source),2), complex)

for i in range(len(Source)):
    Source_PolState[i,0] = 1
    Source_PolState[i,1] = 1j

# %% [markdown]
# #### Circularly polarized illumination patterns

# %%
wo.plot_multicolumn(fftshift(Source_cont,axes=(1,2)), origin='lower', num_col=5)

# %%
# discretized illumination patterns used in simulation (faster forward model)
wo.plot_multicolumn(fftshift(Source,axes=(1,2)), origin='lower', num_col=5, size=10)

# %%
Source_PolState
# Out:
# array([[1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j],
#        [1.+0.j, 0.+1.j]])

# %%
plt.figure(figsize=(10,10))
plt.imshow(fftshift(np.sum(Source,axis=0)), origin='lower')
np.sum(Source,axis=(1,2))
# Out:
# array([ 85.,  78.,  85.,  78.,  85.,  78.,  85.,  78., 160.])

# %% [markdown]
# #### Initialize microscope simulator with above source pattern and uniform imaging pupil

# %%
## initiate the simulator
simulator = wo.waveorder_microscopy_simulator((N,M), lambda_illu, ps, NA_obj, NA_illu, z_defocus, chi, \
                                n_media = n_media, illu_mode = 'Arbitrary', Source=Source, Source_PolState=Source_PolState, use_gpu=use_gpu, gpu_id=gpu_id)

# %% [markdown]
# ## Compute image volumes and Stokes volumes with vectorial simulation

# %%
# forward simulation done by vectorial SEAGLE implementation 
# (when itr_max = 0, we use the first Born approximation)

I_meas_SEAGLE, Stokes_SEAGLE = simulator.simulate_3D_vectorial_measurements_SEAGLE(epsilon_tensor, itr_max = 0, tolerance=1e-4, verbose=True)
# Out:
# Number of point sources considered (1 / 85) in pattern (1 / 9), elapsed time: 1.62
# Number of point sources considered (2 / 85) in pattern (1 / 9), elapsed time: 2.01
# Number of point sources considered (3 / 85) in pattern (1 / 9), elapsed time: 2.39
# Number of point sources considered (4 / 85) in pattern (1 / 9), elapsed time: 2.78
# Number of point sources considered (5 / 85) in pattern (1 / 9), elapsed time: 3.17
# Number of point sources considered (6 / 85) in pattern (1 / 9), elapsed time: 3.58
# Number of point sources considered (7 / 85) in pattern (1 / 9), elapsed time: 3.96
# Number of point sources considered (8 / 85) in pattern (1 / 9), elapsed time: 4.34
# Number of point sources considered (9 / 85) in pattern (1 / 9), elapsed time: 4.73
# Number of point sources considered (10 / 85) in pattern (1 / 9), elapsed time: 5.11
# Number of point sources considered (11 / 85) in pattern (1 / 9), elapsed time: 5.49
# Number of point sources considered (12 / 85) in pattern (1 / 9), elapsed time: 5.88
# Number of point sources considered (13 / 85) in pattern (1 / 9), elapsed time: 6.27
# Number of point sources considered (14 / 85) in pattern (1 / 9), elapsed time: 6.65
# Number of point sources considered (15 / 85) in pattern (1 / 9), elapsed time: 7.04
# Number of point sources considered (16 / 85) in pattern (1 / 9), elapsed time: 7.42
# Number of point sources considered (17 / 85) in pattern (1 / 9), elapsed time: 7.81
# Number of point sources considered (18 / 85) in pattern (1 / 9), elapsed time: 8.20
# Number of point sources considered (19 / 85) in pattern (1 / 9), elapsed time: 8.58
# Number of point sources considered (20 / 85) in pattern (1 / 9), elapsed time: 8.97
# Number of point sources considered (21 / 85) in pattern (1 / 9), elapsed time: 9.36
# Number of point sources considered (22 / 85) in pattern (1 / 9), elapsed time: 9.74
# Number of point sources considered (23 / 85) in pattern (1 / 9), elapsed time: 10.13
# Number of point sources considered (24 / 85) in pattern (1 / 9), elapsed time: 10.52
# Number of point sources considered (25 / 85) in pattern (1 / 9), elapsed time: 10.90
# Number of point sources considered (26 / 85) in pattern (1 / 9), elapsed time: 11.28
# Number of point sources considered (27 / 85) in pattern (1 / 9), elapsed time: 11.67
# Number of point sources considered (28 / 85) in pattern (1 / 9), elapsed time: 12.06
# Number of point sources considered (29 / 85) in pattern (1 / 9), elapsed time: 12.44
# Number of point sources considered (30 / 85) in pattern (1 / 9), elapsed time: 12.83
# Number of point sources considered (31 / 85) in pattern (1 / 9), elapsed time: 13.21
# Number of point sources considered (32 / 85) in pattern (1 / 9), elapsed time: 13.60
# Number of point sources considered (33 / 85) in pattern (1 / 9), elapsed time: 13.98
# Number of point sources considered (34 / 85) in pattern (1 / 9), elapsed time: 14.37
# Number of point sources considered (35 / 85) in pattern (1 / 9), elapsed time: 14.76
# Number of point sources considered (36 / 85) in pattern (1 / 9), elapsed time: 15.14
# Number of point sources considered (37 / 85) in pattern (1 / 9), elapsed time: 15.52
# Number of point sources considered (38 / 85) in pattern (1 / 9), elapsed time: 15.91
# Number of point sources considered (39 / 85) in pattern (1 / 9), elapsed time: 16.29
# Number of point sources considered (40 / 85) in pattern (1 / 9), elapsed time: 16.68
# Number of point sources considered (41 / 85) in pattern (1 / 9), elapsed time: 17.06
# Number of point sources considered (42 / 85) in pattern (1 / 9), elapsed time: 17.45
# Number of point sources considered (43 / 85) in pattern (1 / 9), elapsed time: 17.83
# Number of point sources considered (44 / 85) in pattern (1 / 9), elapsed time: 18.22
# Number of point sources considered (45 / 85) in pattern (1 / 9), elapsed time: 18.61
# Number of point sources considered (46 / 85) in pattern (1 / 9), elapsed time: 18.99
# Number of point sources considered (47 / 85) in pattern (1 / 9), elapsed time: 19.38
# Number of point sources considered (48 / 85) in pattern (1 / 9), elapsed time: 19.76
# Number of point sources considered (49 / 85) in pattern (1 / 9), elapsed time: 20.15
# Number of point sources considered (50 / 85) in pattern (1 / 9), elapsed time: 20.53
# Number of point sources considered (51 / 85) in pattern (1 / 9), elapsed time: 20.92
# Number of point sources considered (52 / 85) in pattern (1 / 9), elapsed time: 21.30
# Number of point sources considered (53 / 85) in pattern (1 / 9), elapsed time: 21.68
# Number of point sources considered (54 / 85) in pattern (1 / 9), elapsed time: 22.07
# Number of point sources considered (55 / 85) in pattern (1 / 9), elapsed time: 22.45
# Number of point sources considered (56 / 85) in pattern (1 / 9), elapsed time: 22.83
# Number of point sources considered (57 / 85) in pattern (1 / 9), elapsed time: 23.22
# Number of point sources considered (58 / 85) in pattern (1 / 9), elapsed time: 23.60
# Number of point sources considered (59 / 85) in pattern (1 / 9), elapsed time: 23.99
# Number of point sources considered (60 / 85) in pattern (1 / 9), elapsed time: 24.37
# Number of point sources considered (61 / 85) in pattern (1 / 9), elapsed time: 24.76
# Number of point sources considered (62 / 85) in pattern (1 / 9), elapsed time: 25.14
# Number of point sources considered (63 / 85) in pattern (1 / 9), elapsed time: 25.52
# Number of point sources considered (64 / 85) in pattern (1 / 9), elapsed time: 25.91
# Number of point sources considered (65 / 85) in pattern (1 / 9), elapsed time: 26.29
# Number of point sources considered (66 / 85) in pattern (1 / 9), elapsed time: 26.68
# Number of point sources considered (67 / 85) in pattern (1 / 9), elapsed time: 27.06
# Number of point sources considered (68 / 85) in pattern (1 / 9), elapsed time: 27.44
# Number of point sources considered (69 / 85) in pattern (1 / 9), elapsed time: 27.83
# Number of point sources considered (70 / 85) in pattern (1 / 9), elapsed time: 28.21
# Number of point sources considered (71 / 85) in pattern (1 / 9), elapsed time: 28.60
# Number of point sources considered (72 / 85) in pattern (1 / 9), elapsed time: 28.98
# Number of point sources considered (73 / 85) in pattern (1 / 9), elapsed time: 29.37
# Number of point sources considered (74 / 85) in pattern (1 / 9), elapsed time: 29.75
# Number of point sources considered (75 / 85) in pattern (1 / 9), elapsed time: 30.14
# Number of point sources considered (76 / 85) in pattern (1 / 9), elapsed time: 30.53
# Number of point sources considered (77 / 85) in pattern (1 / 9), elapsed time: 30.91
# Number of point sources considered (78 / 85) in pattern (1 / 9), elapsed time: 31.30
# Number of point sources considered (79 / 85) in pattern (1 / 9), elapsed time: 31.68
# Number of point sources considered (80 / 85) in pattern (1 / 9), elapsed time: 32.07
# Number of point sources considered (81 / 85) in pattern (1 / 9), elapsed time: 32.45
# Number of point sources considered (82 / 85) in pattern (1 / 9), elapsed time: 32.84
# Number of point sources considered (83 / 85) in pattern (1 / 9), elapsed time: 33.22
# Number of point sources considered (84 / 85) in pattern (1 / 9), elapsed time: 33.62
# Number of point sources considered (85 / 85) in pattern (1 / 9), elapsed time: 34.00
# Number of point sources considered (1 / 78) in pattern (2 / 9), elapsed time: 34.49
# Number of point sources considered (2 / 78) in pattern (2 / 9), elapsed time: 34.87
# Number of point sources considered (3 / 78) in pattern (2 / 9), elapsed time: 35.25
# Number of point sources considered (4 / 78) in pattern (2 / 9), elapsed time: 35.64
# Number of point sources considered (5 / 78) in pattern (2 / 9), elapsed time: 36.02
# Number of point sources considered (6 / 78) in pattern (2 / 9), elapsed time: 36.40
# Number of point sources considered (7 / 78) in pattern (2 / 9), elapsed time: 36.78
# Number of point sources considered (8 / 78) in pattern (2 / 9), elapsed time: 37.17
# Number of point sources considered (9 / 78) in pattern (2 / 9), elapsed time: 37.57
# Number of point sources considered (10 / 78) in pattern (2 / 9), elapsed time: 37.95
# Number of point sources considered (11 / 78) in pattern (2 / 9), elapsed time: 38.33
# Number of point sources considered (12 / 78) in pattern (2 / 9), elapsed time: 38.72
# Number of point sources considered (13 / 78) in pattern (2 / 9), elapsed time: 39.10
# Number of point sources considered (14 / 78) in pattern (2 / 9), elapsed time: 39.48
# Number of point sources considered (15 / 78) in pattern (2 / 9), elapsed time: 39.86
# Number of point sources considered (16 / 78) in pattern (2 / 9), elapsed time: 40.25
# Number of point sources considered (17 / 78) in pattern (2 / 9), elapsed time: 40.63
# Number of point sources considered (18 / 78) in pattern (2 / 9), elapsed time: 41.01
# Number of point sources considered (19 / 78) in pattern (2 / 9), elapsed time: 41.40
# Number of point sources considered (20 / 78) in pattern (2 / 9), elapsed time: 41.78
# Number of point sources considered (21 / 78) in pattern (2 / 9), elapsed time: 42.17
# Number of point sources considered (22 / 78) in pattern (2 / 9), elapsed time: 42.55
# Number of point sources considered (23 / 78) in pattern (2 / 9), elapsed time: 42.93
# Number of point sources considered (24 / 78) in pattern (2 / 9), elapsed time: 43.32
# Number of point sources considered (25 / 78) in pattern (2 / 9), elapsed time: 43.70
# Number of point sources considered (26 / 78) in pattern (2 / 9), elapsed time: 44.09
# Number of point sources considered (27 / 78) in pattern (2 / 9), elapsed time: 44.47
# Number of point sources considered (28 / 78) in pattern (2 / 9), elapsed time: 44.85
# Number of point sources considered (29 / 78) in pattern (2 / 9), elapsed time: 45.24
# Number of point sources considered (30 / 78) in pattern (2 / 9), elapsed time: 45.62
# Number of point sources considered (31 / 78) in pattern (2 / 9), elapsed time: 46.00
# Number of point sources considered (32 / 78) in pattern (2 / 9), elapsed time: 46.38
# Number of point sources considered (33 / 78) in pattern (2 / 9), elapsed time: 46.77
# Number of point sources considered (34 / 78) in pattern (2 / 9), elapsed time: 47.15
# Number of point sources considered (35 / 78) in pattern (2 / 9), elapsed time: 47.54
# Number of point sources considered (36 / 78) in pattern (2 / 9), elapsed time: 47.92
# Number of point sources considered (37 / 78) in pattern (2 / 9), elapsed time: 48.30
# Number of point sources considered (38 / 78) in pattern (2 / 9), elapsed time: 48.69
# Number of point sources considered (39 / 78) in pattern (2 / 9), elapsed time: 49.08
# Number of point sources considered (40 / 78) in pattern (2 / 9), elapsed time: 49.48
# Number of point sources considered (41 / 78) in pattern (2 / 9), elapsed time: 49.87
# Number of point sources considered (42 / 78) in pattern (2 / 9), elapsed time: 50.25
# Number of point sources considered (43 / 78) in pattern (2 / 9), elapsed time: 50.63
# Number of point sources considered (44 / 78) in pattern (2 / 9), elapsed time: 51.01
# Number of point sources considered (45 / 78) in pattern (2 / 9), elapsed time: 51.40
# Number of point sources considered (46 / 78) in pattern (2 / 9), elapsed time: 51.78
# Number of point sources considered (47 / 78) in pattern (2 / 9), elapsed time: 52.16
# Number of point sources considered (48 / 78) in pattern (2 / 9), elapsed time: 52.55
# Number of point sources considered (49 / 78) in pattern (2 / 9), elapsed time: 52.93
# Number of point sources considered (50 / 78) in pattern (2 / 9), elapsed time: 53.32
# Number of point sources considered (51 / 78) in pattern (2 / 9), elapsed time: 53.70
# Number of point sources considered (52 / 78) in pattern (2 / 9), elapsed time: 54.09
# Number of point sources considered (53 / 78) in pattern (2 / 9), elapsed time: 54.47
# Number of point sources considered (54 / 78) in pattern (2 / 9), elapsed time: 54.85
# Number of point sources considered (55 / 78) in pattern (2 / 9), elapsed time: 55.23
# Number of point sources considered (56 / 78) in pattern (2 / 9), elapsed time: 55.61
# Number of point sources considered (57 / 78) in pattern (2 / 9), elapsed time: 56.00
# Number of point sources considered (58 / 78) in pattern (2 / 9), elapsed time: 56.38
# Number of point sources considered (59 / 78) in pattern (2 / 9), elapsed time: 56.77
# Number of point sources considered (60 / 78) in pattern (2 / 9), elapsed time: 57.16
# Number of point sources considered (61 / 78) in pattern (2 / 9), elapsed time: 57.54
# Number of point sources considered (62 / 78) in pattern (2 / 9), elapsed time: 57.92
# Number of point sources considered (63 / 78) in pattern (2 / 9), elapsed time: 58.31
# Number of point sources considered (64 / 78) in pattern (2 / 9), elapsed time: 58.69
# Number of point sources considered (65 / 78) in pattern (2 / 9), elapsed time: 59.07
# Number of point sources considered (66 / 78) in pattern (2 / 9), elapsed time: 59.46
# Number of point sources considered (67 / 78) in pattern (2 / 9), elapsed time: 59.84
# Number of point sources considered (68 / 78) in pattern (2 / 9), elapsed time: 60.23
# Number of point sources considered (69 / 78) in pattern (2 / 9), elapsed time: 60.62
# Number of point sources considered (70 / 78) in pattern (2 / 9), elapsed time: 61.00
# Number of point sources considered (71 / 78) in pattern (2 / 9), elapsed time: 61.39
# Number of point sources considered (72 / 78) in pattern (2 / 9), elapsed time: 61.77
# Number of point sources considered (73 / 78) in pattern (2 / 9), elapsed time: 62.15
# Number of point sources considered (74 / 78) in pattern (2 / 9), elapsed time: 62.54
# Number of point sources considered (75 / 78) in pattern (2 / 9), elapsed time: 62.93
# Number of point sources considered (76 / 78) in pattern (2 / 9), elapsed time: 63.31
# Number of point sources considered (77 / 78) in pattern (2 / 9), elapsed time: 63.70
# Number of point sources considered (78 / 78) in pattern (2 / 9), elapsed time: 64.08
# Number of point sources considered (1 / 85) in pattern (3 / 9), elapsed time: 64.56
# Number of point sources considered (2 / 85) in pattern (3 / 9), elapsed time: 64.94
# Number of point sources considered (3 / 85) in pattern (3 / 9), elapsed time: 65.33
# Number of point sources considered (4 / 85) in pattern (3 / 9), elapsed time: 65.71
# Number of point sources considered (5 / 85) in pattern (3 / 9), elapsed time: 66.09
# Number of point sources considered (6 / 85) in pattern (3 / 9), elapsed time: 66.47
# Number of point sources considered (7 / 85) in pattern (3 / 9), elapsed time: 66.85
# Number of point sources considered (8 / 85) in pattern (3 / 9), elapsed time: 67.23
# Number of point sources considered (9 / 85) in pattern (3 / 9), elapsed time: 67.62
# Number of point sources considered (10 / 85) in pattern (3 / 9), elapsed time: 68.00
# Number of point sources considered (11 / 85) in pattern (3 / 9), elapsed time: 68.38
# Number of point sources considered (12 / 85) in pattern (3 / 9), elapsed time: 68.76
# Number of point sources considered (13 / 85) in pattern (3 / 9), elapsed time: 69.16
# Number of point sources considered (14 / 85) in pattern (3 / 9), elapsed time: 69.56
# Number of point sources considered (15 / 85) in pattern (3 / 9), elapsed time: 69.96
# Number of point sources considered (16 / 85) in pattern (3 / 9), elapsed time: 70.34
# Number of point sources considered (17 / 85) in pattern (3 / 9), elapsed time: 70.72
# Number of point sources considered (18 / 85) in pattern (3 / 9), elapsed time: 71.10
# Number of point sources considered (19 / 85) in pattern (3 / 9), elapsed time: 71.49
# Number of point sources considered (20 / 85) in pattern (3 / 9), elapsed time: 71.87
# Number of point sources considered (21 / 85) in pattern (3 / 9), elapsed time: 72.25
# Number of point sources considered (22 / 85) in pattern (3 / 9), elapsed time: 72.66
# Number of point sources considered (23 / 85) in pattern (3 / 9), elapsed time: 73.05
# Number of point sources considered (24 / 85) in pattern (3 / 9), elapsed time: 73.43
# Number of point sources considered (25 / 85) in pattern (3 / 9), elapsed time: 73.81
# Number of point sources considered (26 / 85) in pattern (3 / 9), elapsed time: 74.19
# Number of point sources considered (27 / 85) in pattern (3 / 9), elapsed time: 74.58
# Number of point sources considered (28 / 85) in pattern (3 / 9), elapsed time: 74.96
# Number of point sources considered (29 / 85) in pattern (3 / 9), elapsed time: 75.34
# Number of point sources considered (30 / 85) in pattern (3 / 9), elapsed time: 75.72
# Number of point sources considered (31 / 85) in pattern (3 / 9), elapsed time: 76.10
# Number of point sources considered (32 / 85) in pattern (3 / 9), elapsed time: 76.49
# Number of point sources considered (33 / 85) in pattern (3 / 9), elapsed time: 76.87
# Number of point sources considered (34 / 85) in pattern (3 / 9), elapsed time: 77.26
# Number of point sources considered (35 / 85) in pattern (3 / 9), elapsed time: 77.64
# Number of point sources considered (36 / 85) in pattern (3 / 9), elapsed time: 78.03
# Number of point sources considered (37 / 85) in pattern (3 / 9), elapsed time: 78.41
# Number of point sources considered (38 / 85) in pattern (3 / 9), elapsed time: 78.79
# Number of point sources considered (39 / 85) in pattern (3 / 9), elapsed time: 79.18
# Number of point sources considered (40 / 85) in pattern (3 / 9), elapsed time: 79.56
# Number of point sources considered (41 / 85) in pattern (3 / 9), elapsed time: 79.95
# Number of point sources considered (42 / 85) in pattern (3 / 9), elapsed time: 80.33
# Number of point sources considered (43 / 85) in pattern (3 / 9), elapsed time: 80.71
# Number of point sources considered (44 / 85) in pattern (3 / 9), elapsed time: 81.10
# Number of point sources considered (45 / 85) in pattern (3 / 9), elapsed time: 81.48
# Number of point sources considered (46 / 85) in pattern (3 / 9), elapsed time: 81.86
# Number of point sources considered (47 / 85) in pattern (3 / 9), elapsed time: 82.25
# Number of point sources considered (48 / 85) in pattern (3 / 9), elapsed time: 82.63
# Number of point sources considered (49 / 85) in pattern (3 / 9), elapsed time: 83.01
# Number of point sources considered (50 / 85) in pattern (3 / 9), elapsed time: 83.39
# Number of point sources considered (51 / 85) in pattern (3 / 9), elapsed time: 83.78
# Number of point sources considered (52 / 85) in pattern (3 / 9), elapsed time: 84.16
# Number of point sources considered (53 / 85) in pattern (3 / 9), elapsed time: 84.54
# Number of point sources considered (54 / 85) in pattern (3 / 9), elapsed time: 84.93
# Number of point sources considered (55 / 85) in pattern (3 / 9), elapsed time: 85.31
# Number of point sources considered (56 / 85) in pattern (3 / 9), elapsed time: 85.69
# Number of point sources considered (57 / 85) in pattern (3 / 9), elapsed time: 86.08
# Number of point sources considered (58 / 85) in pattern (3 / 9), elapsed time: 86.46
# Number of point sources considered (59 / 85) in pattern (3 / 9), elapsed time: 86.84
# Number of point sources considered (60 / 85) in pattern (3 / 9), elapsed time: 87.22
# Number of point sources considered (61 / 85) in pattern (3 / 9), elapsed time: 87.61
# Number of point sources considered (62 / 85) in pattern (3 / 9), elapsed time: 87.99
# Number of point sources considered (63 / 85) in pattern (3 / 9), elapsed time: 88.37
# Number of point sources considered (64 / 85) in pattern (3 / 9), elapsed time: 88.75
# Number of point sources considered (65 / 85) in pattern (3 / 9), elapsed time: 89.14
# Number of point sources considered (66 / 85) in pattern (3 / 9), elapsed time: 89.52
# Number of point sources considered (67 / 85) in pattern (3 / 9), elapsed time: 89.92
# Number of point sources considered (68 / 85) in pattern (3 / 9), elapsed time: 90.30
# Number of point sources considered (69 / 85) in pattern (3 / 9), elapsed time: 90.69
# Number of point sources considered (70 / 85) in pattern (3 / 9), elapsed time: 91.08
# Number of point sources considered (71 / 85) in pattern (3 / 9), elapsed time: 91.47
# Number of point sources considered (72 / 85) in pattern (3 / 9), elapsed time: 91.85
# Number of point sources considered (73 / 85) in pattern (3 / 9), elapsed time: 92.24
# Number of point sources considered (74 / 85) in pattern (3 / 9), elapsed time: 92.62
# Number of point sources considered (75 / 85) in pattern (3 / 9), elapsed time: 93.01
# Number of point sources considered (76 / 85) in pattern (3 / 9), elapsed time: 93.39
# Number of point sources considered (77 / 85) in pattern (3 / 9), elapsed time: 93.77
# Number of point sources considered (78 / 85) in pattern (3 / 9), elapsed time: 94.15
# Number of point sources considered (79 / 85) in pattern (3 / 9), elapsed time: 94.53
# Number of point sources considered (80 / 85) in pattern (3 / 9), elapsed time: 94.91
# Number of point sources considered (81 / 85) in pattern (3 / 9), elapsed time: 95.30
# Number of point sources considered (82 / 85) in pattern (3 / 9), elapsed time: 95.68
# Number of point sources considered (83 / 85) in pattern (3 / 9), elapsed time: 96.06
# Number of point sources considered (84 / 85) in pattern (3 / 9), elapsed time: 96.44
# Number of point sources considered (85 / 85) in pattern (3 / 9), elapsed time: 96.83
# Number of point sources considered (1 / 78) in pattern (4 / 9), elapsed time: 97.31
# Number of point sources considered (2 / 78) in pattern (4 / 9), elapsed time: 97.69
# Number of point sources considered (3 / 78) in pattern (4 / 9), elapsed time: 98.08
# Number of point sources considered (4 / 78) in pattern (4 / 9), elapsed time: 98.46
# Number of point sources considered (5 / 78) in pattern (4 / 9), elapsed time: 98.84
# Number of point sources considered (6 / 78) in pattern (4 / 9), elapsed time: 99.22
# Number of point sources considered (7 / 78) in pattern (4 / 9), elapsed time: 99.61
# Number of point sources considered (8 / 78) in pattern (4 / 9), elapsed time: 99.99
# Number of point sources considered (9 / 78) in pattern (4 / 9), elapsed time: 100.37
# Number of point sources considered (10 / 78) in pattern (4 / 9), elapsed time: 100.76
# Number of point sources considered (11 / 78) in pattern (4 / 9), elapsed time: 101.14
# Number of point sources considered (12 / 78) in pattern (4 / 9), elapsed time: 101.53
# Number of point sources considered (13 / 78) in pattern (4 / 9), elapsed time: 101.91
# Number of point sources considered (14 / 78) in pattern (4 / 9), elapsed time: 102.29
# Number of point sources considered (15 / 78) in pattern (4 / 9), elapsed time: 102.67
# Number of point sources considered (16 / 78) in pattern (4 / 9), elapsed time: 103.06
# Number of point sources considered (17 / 78) in pattern (4 / 9), elapsed time: 103.44
# Number of point sources considered (18 / 78) in pattern (4 / 9), elapsed time: 103.83
# Number of point sources considered (19 / 78) in pattern (4 / 9), elapsed time: 104.22
# Number of point sources considered (20 / 78) in pattern (4 / 9), elapsed time: 104.61
# Number of point sources considered (21 / 78) in pattern (4 / 9), elapsed time: 104.99
# Number of point sources considered (22 / 78) in pattern (4 / 9), elapsed time: 105.38
# Number of point sources considered (23 / 78) in pattern (4 / 9), elapsed time: 105.77
# Number of point sources considered (24 / 78) in pattern (4 / 9), elapsed time: 106.15
# Number of point sources considered (25 / 78) in pattern (4 / 9), elapsed time: 106.54
# Number of point sources considered (26 / 78) in pattern (4 / 9), elapsed time: 106.92
# Number of point sources considered (27 / 78) in pattern (4 / 9), elapsed time: 107.32
# Number of point sources considered (28 / 78) in pattern (4 / 9), elapsed time: 107.70
# Number of point sources considered (29 / 78) in pattern (4 / 9), elapsed time: 108.10
# Number of point sources considered (30 / 78) in pattern (4 / 9), elapsed time: 108.50
# Number of point sources considered (31 / 78) in pattern (4 / 9), elapsed time: 108.90
# Number of point sources considered (32 / 78) in pattern (4 / 9), elapsed time: 109.30
# Number of point sources considered (33 / 78) in pattern (4 / 9), elapsed time: 109.70
# Number of point sources considered (34 / 78) in pattern (4 / 9), elapsed time: 110.10
# Number of point sources considered (35 / 78) in pattern (4 / 9), elapsed time: 110.49
# Number of point sources considered (36 / 78) in pattern (4 / 9), elapsed time: 110.87
# Number of point sources considered (37 / 78) in pattern (4 / 9), elapsed time: 111.25
# Number of point sources considered (38 / 78) in pattern (4 / 9), elapsed time: 111.64
# Number of point sources considered (39 / 78) in pattern (4 / 9), elapsed time: 112.02
# Number of point sources considered (40 / 78) in pattern (4 / 9), elapsed time: 112.40
# Number of point sources considered (41 / 78) in pattern (4 / 9), elapsed time: 112.80
# Number of point sources considered (42 / 78) in pattern (4 / 9), elapsed time: 113.20
# Number of point sources considered (43 / 78) in pattern (4 / 9), elapsed time: 113.59
# Number of point sources considered (44 / 78) in pattern (4 / 9), elapsed time: 113.99
# Number of point sources considered (45 / 78) in pattern (4 / 9), elapsed time: 114.39
# Number of point sources considered (46 / 78) in pattern (4 / 9), elapsed time: 114.79
# Number of point sources considered (47 / 78) in pattern (4 / 9), elapsed time: 115.19
# Number of point sources considered (48 / 78) in pattern (4 / 9), elapsed time: 115.59
# Number of point sources considered (49 / 78) in pattern (4 / 9), elapsed time: 115.99
# Number of point sources considered (50 / 78) in pattern (4 / 9), elapsed time: 116.37
# Number of point sources considered (51 / 78) in pattern (4 / 9), elapsed time: 116.76
# Number of point sources considered (52 / 78) in pattern (4 / 9), elapsed time: 117.14
# Number of point sources considered (53 / 78) in pattern (4 / 9), elapsed time: 117.54
# Number of point sources considered (54 / 78) in pattern (4 / 9), elapsed time: 117.92
# Number of point sources considered (55 / 78) in pattern (4 / 9), elapsed time: 118.32
# Number of point sources considered (56 / 78) in pattern (4 / 9), elapsed time: 118.70
# Number of point sources considered (57 / 78) in pattern (4 / 9), elapsed time: 119.10
# Number of point sources considered (58 / 78) in pattern (4 / 9), elapsed time: 119.49
# Number of point sources considered (59 / 78) in pattern (4 / 9), elapsed time: 119.91
# Number of point sources considered (60 / 78) in pattern (4 / 9), elapsed time: 120.32
# Number of point sources considered (61 / 78) in pattern (4 / 9), elapsed time: 120.70
# Number of point sources considered (62 / 78) in pattern (4 / 9), elapsed time: 121.11
# Number of point sources considered (63 / 78) in pattern (4 / 9), elapsed time: 121.49
# Number of point sources considered (64 / 78) in pattern (4 / 9), elapsed time: 121.88
# Number of point sources considered (65 / 78) in pattern (4 / 9), elapsed time: 122.26
# Number of point sources considered (66 / 78) in pattern (4 / 9), elapsed time: 122.65
# Number of point sources considered (67 / 78) in pattern (4 / 9), elapsed time: 123.05
# Number of point sources considered (68 / 78) in pattern (4 / 9), elapsed time: 123.45
# Number of point sources considered (69 / 78) in pattern (4 / 9), elapsed time: 123.85
# Number of point sources considered (70 / 78) in pattern (4 / 9), elapsed time: 124.25
# Number of point sources considered (71 / 78) in pattern (4 / 9), elapsed time: 124.65
# Number of point sources considered (72 / 78) in pattern (4 / 9), elapsed time: 125.03
# Number of point sources considered (73 / 78) in pattern (4 / 9), elapsed time: 125.44
# Number of point sources considered (74 / 78) in pattern (4 / 9), elapsed time: 125.84
# Number of point sources considered (75 / 78) in pattern (4 / 9), elapsed time: 126.25
# Number of point sources considered (76 / 78) in pattern (4 / 9), elapsed time: 126.63
# Number of point sources considered (77 / 78) in pattern (4 / 9), elapsed time: 127.02
# Number of point sources considered (78 / 78) in pattern (4 / 9), elapsed time: 127.42
# Number of point sources considered (1 / 85) in pattern (5 / 9), elapsed time: 127.93
# Number of point sources considered (2 / 85) in pattern (5 / 9), elapsed time: 128.32
# Number of point sources considered (3 / 85) in pattern (5 / 9), elapsed time: 128.72
# Number of point sources considered (4 / 85) in pattern (5 / 9), elapsed time: 129.12
# Number of point sources considered (5 / 85) in pattern (5 / 9), elapsed time: 129.52
# Number of point sources considered (6 / 85) in pattern (5 / 9), elapsed time: 129.95
# Number of point sources considered (7 / 85) in pattern (5 / 9), elapsed time: 130.34
# Number of point sources considered (8 / 85) in pattern (5 / 9), elapsed time: 130.74
# Number of point sources considered (9 / 85) in pattern (5 / 9), elapsed time: 131.12
# Number of point sources considered (10 / 85) in pattern (5 / 9), elapsed time: 131.51
# Number of point sources considered (11 / 85) in pattern (5 / 9), elapsed time: 131.90
# Number of point sources considered (12 / 85) in pattern (5 / 9), elapsed time: 132.30
# Number of point sources considered (13 / 85) in pattern (5 / 9), elapsed time: 132.69
# Number of point sources considered (14 / 85) in pattern (5 / 9), elapsed time: 133.09
# Number of point sources considered (15 / 85) in pattern (5 / 9), elapsed time: 133.49
# Number of point sources considered (16 / 85) in pattern (5 / 9), elapsed time: 133.89
# Number of point sources considered (17 / 85) in pattern (5 / 9), elapsed time: 134.29
# Number of point sources considered (18 / 85) in pattern (5 / 9), elapsed time: 134.67
# Number of point sources considered (19 / 85) in pattern (5 / 9), elapsed time: 135.07
# Number of point sources considered (20 / 85) in pattern (5 / 9), elapsed time: 135.47
# Number of point sources considered (21 / 85) in pattern (5 / 9), elapsed time: 135.87
# Number of point sources considered (22 / 85) in pattern (5 / 9), elapsed time: 136.27
# Number of point sources considered (23 / 85) in pattern (5 / 9), elapsed time: 136.66
# Number of point sources considered (24 / 85) in pattern (5 / 9), elapsed time: 137.06
# Number of point sources considered (25 / 85) in pattern (5 / 9), elapsed time: 137.44
# Number of point sources considered (26 / 85) in pattern (5 / 9), elapsed time: 137.84
# Number of point sources considered (27 / 85) in pattern (5 / 9), elapsed time: 138.24
# Number of point sources considered (28 / 85) in pattern (5 / 9), elapsed time: 138.64
# Number of point sources considered (29 / 85) in pattern (5 / 9), elapsed time: 139.02
# Number of point sources considered (30 / 85) in pattern (5 / 9), elapsed time: 139.42
# Number of point sources considered (31 / 85) in pattern (5 / 9), elapsed time: 139.82
# Number of point sources considered (32 / 85) in pattern (5 / 9), elapsed time: 140.22
# Number of point sources considered (33 / 85) in pattern (5 / 9), elapsed time: 140.63
# Number of point sources considered (34 / 85) in pattern (5 / 9), elapsed time: 141.02
# Number of point sources considered (35 / 85) in pattern (5 / 9), elapsed time: 141.41
# Number of point sources considered (36 / 85) in pattern (5 / 9), elapsed time: 141.79
# Number of point sources considered (37 / 85) in pattern (5 / 9), elapsed time: 142.19
# Number of point sources considered (38 / 85) in pattern (5 / 9), elapsed time: 142.58
# Number of point sources considered (39 / 85) in pattern (5 / 9), elapsed time: 142.96
# Number of point sources considered (40 / 85) in pattern (5 / 9), elapsed time: 143.36
# Number of point sources considered (41 / 85) in pattern (5 / 9), elapsed time: 143.76
# Number of point sources considered (42 / 85) in pattern (5 / 9), elapsed time: 144.16
# Number of point sources considered (43 / 85) in pattern (5 / 9), elapsed time: 144.56
# Number of point sources considered (44 / 85) in pattern (5 / 9), elapsed time: 144.95
# Number of point sources considered (45 / 85) in pattern (5 / 9), elapsed time: 145.33
# Number of point sources considered (46 / 85) in pattern (5 / 9), elapsed time: 145.72
# Number of point sources considered (47 / 85) in pattern (5 / 9), elapsed time: 146.10
# Number of point sources considered (48 / 85) in pattern (5 / 9), elapsed time: 146.49
# Number of point sources considered (49 / 85) in pattern (5 / 9), elapsed time: 146.87
# Number of point sources considered (50 / 85) in pattern (5 / 9), elapsed time: 147.26
# Number of point sources considered (51 / 85) in pattern (5 / 9), elapsed time: 147.64
# Number of point sources considered (52 / 85) in pattern (5 / 9), elapsed time: 148.03
# Number of point sources considered (53 / 85) in pattern (5 / 9), elapsed time: 148.41
# Number of point sources considered (54 / 85) in pattern (5 / 9), elapsed time: 148.79
# Number of point sources considered (55 / 85) in pattern (5 / 9), elapsed time: 149.18
# Number of point sources considered (56 / 85) in pattern (5 / 9), elapsed time: 149.56
# Number of point sources considered (57 / 85) in pattern (5 / 9), elapsed time: 149.95
# Number of point sources considered (58 / 85) in pattern (5 / 9), elapsed time: 150.34
# Number of point sources considered (59 / 85) in pattern (5 / 9), elapsed time: 150.73
# Number of point sources considered (60 / 85) in pattern (5 / 9), elapsed time: 151.11
# Number of point sources considered (61 / 85) in pattern (5 / 9), elapsed time: 151.50
# Number of point sources considered (62 / 85) in pattern (5 / 9), elapsed time: 151.88
# Number of point sources considered (63 / 85) in pattern (5 / 9), elapsed time: 152.26
# Number of point sources considered (64 / 85) in pattern (5 / 9), elapsed time: 152.65
# Number of point sources considered (65 / 85) in pattern (5 / 9), elapsed time: 153.03
# Number of point sources considered (66 / 85) in pattern (5 / 9), elapsed time: 153.41
# Number of point sources considered (67 / 85) in pattern (5 / 9), elapsed time: 153.80
# Number of point sources considered (68 / 85) in pattern (5 / 9), elapsed time: 154.18
# Number of point sources considered (69 / 85) in pattern (5 / 9), elapsed time: 154.57
# Number of point sources considered (70 / 85) in pattern (5 / 9), elapsed time: 154.95
# Number of point sources considered (71 / 85) in pattern (5 / 9), elapsed time: 155.33
# Number of point sources considered (72 / 85) in pattern (5 / 9), elapsed time: 155.72
# Number of point sources considered (73 / 85) in pattern (5 / 9), elapsed time: 156.10
# Number of point sources considered (74 / 85) in pattern (5 / 9), elapsed time: 156.49
# Number of point sources considered (75 / 85) in pattern (5 / 9), elapsed time: 156.87
# Number of point sources considered (76 / 85) in pattern (5 / 9), elapsed time: 157.26
# Number of point sources considered (77 / 85) in pattern (5 / 9), elapsed time: 157.64
# Number of point sources considered (78 / 85) in pattern (5 / 9), elapsed time: 158.03
# Number of point sources considered (79 / 85) in pattern (5 / 9), elapsed time: 158.41
# Number of point sources considered (80 / 85) in pattern (5 / 9), elapsed time: 158.80
# Number of point sources considered (81 / 85) in pattern (5 / 9), elapsed time: 159.18
# Number of point sources considered (82 / 85) in pattern (5 / 9), elapsed time: 159.57
# Number of point sources considered (83 / 85) in pattern (5 / 9), elapsed time: 159.95
# Number of point sources considered (84 / 85) in pattern (5 / 9), elapsed time: 160.34
# Number of point sources considered (85 / 85) in pattern (5 / 9), elapsed time: 160.72
# Number of point sources considered (1 / 78) in pattern (6 / 9), elapsed time: 161.21
# Number of point sources considered (2 / 78) in pattern (6 / 9), elapsed time: 161.60
# Number of point sources considered (3 / 78) in pattern (6 / 9), elapsed time: 161.98
# Number of point sources considered (4 / 78) in pattern (6 / 9), elapsed time: 162.38
# Number of point sources considered (5 / 78) in pattern (6 / 9), elapsed time: 162.76
# Number of point sources considered (6 / 78) in pattern (6 / 9), elapsed time: 163.14
# Number of point sources considered (7 / 78) in pattern (6 / 9), elapsed time: 163.53
# Number of point sources considered (8 / 78) in pattern (6 / 9), elapsed time: 163.91
# Number of point sources considered (9 / 78) in pattern (6 / 9), elapsed time: 164.30
# Number of point sources considered (10 / 78) in pattern (6 / 9), elapsed time: 164.68
# Number of point sources considered (11 / 78) in pattern (6 / 9), elapsed time: 165.06
# Number of point sources considered (12 / 78) in pattern (6 / 9), elapsed time: 165.45
# Number of point sources considered (13 / 78) in pattern (6 / 9), elapsed time: 165.83
# Number of point sources considered (14 / 78) in pattern (6 / 9), elapsed time: 166.21
# Number of point sources considered (15 / 78) in pattern (6 / 9), elapsed time: 166.60
# Number of point sources considered (16 / 78) in pattern (6 / 9), elapsed time: 166.98
# Number of point sources considered (17 / 78) in pattern (6 / 9), elapsed time: 167.37
# Number of point sources considered (18 / 78) in pattern (6 / 9), elapsed time: 167.75
# Number of point sources considered (19 / 78) in pattern (6 / 9), elapsed time: 168.14
# Number of point sources considered (20 / 78) in pattern (6 / 9), elapsed time: 168.53
# Number of point sources considered (21 / 78) in pattern (6 / 9), elapsed time: 168.91
# Number of point sources considered (22 / 78) in pattern (6 / 9), elapsed time: 169.30
# Number of point sources considered (23 / 78) in pattern (6 / 9), elapsed time: 169.68
# Number of point sources considered (24 / 78) in pattern (6 / 9), elapsed time: 170.06
# Number of point sources considered (25 / 78) in pattern (6 / 9), elapsed time: 170.45
# Number of point sources considered (26 / 78) in pattern (6 / 9), elapsed time: 170.84
# Number of point sources considered (27 / 78) in pattern (6 / 9), elapsed time: 171.23
# Number of point sources considered (28 / 78) in pattern (6 / 9), elapsed time: 171.62
# Number of point sources considered (29 / 78) in pattern (6 / 9), elapsed time: 172.01
# Number of point sources considered (30 / 78) in pattern (6 / 9), elapsed time: 172.40
# Number of point sources considered (31 / 78) in pattern (6 / 9), elapsed time: 172.78
# Number of point sources considered (32 / 78) in pattern (6 / 9), elapsed time: 173.17
# Number of point sources considered (33 / 78) in pattern (6 / 9), elapsed time: 173.55
# Number of point sources considered (34 / 78) in pattern (6 / 9), elapsed time: 173.94
# Number of point sources considered (35 / 78) in pattern (6 / 9), elapsed time: 174.33
# Number of point sources considered (36 / 78) in pattern (6 / 9), elapsed time: 174.71
# Number of point sources considered (37 / 78) in pattern (6 / 9), elapsed time: 175.09
# Number of point sources considered (38 / 78) in pattern (6 / 9), elapsed time: 175.48
# Number of point sources considered (39 / 78) in pattern (6 / 9), elapsed time: 175.87
# Number of point sources considered (40 / 78) in pattern (6 / 9), elapsed time: 176.25
# Number of point sources considered (41 / 78) in pattern (6 / 9), elapsed time: 176.63
# Number of point sources considered (42 / 78) in pattern (6 / 9), elapsed time: 177.02
# Number of point sources considered (43 / 78) in pattern (6 / 9), elapsed time: 177.40
# Number of point sources considered (44 / 78) in pattern (6 / 9), elapsed time: 177.78
# Number of point sources considered (45 / 78) in pattern (6 / 9), elapsed time: 178.17
# Number of point sources considered (46 / 78) in pattern (6 / 9), elapsed time: 178.57
# Number of point sources considered (47 / 78) in pattern (6 / 9), elapsed time: 178.97
# Number of point sources considered (48 / 78) in pattern (6 / 9), elapsed time: 179.36
# Number of point sources considered (49 / 78) in pattern (6 / 9), elapsed time: 179.76
# Number of point sources considered (50 / 78) in pattern (6 / 9), elapsed time: 180.16
# Number of point sources considered (51 / 78) in pattern (6 / 9), elapsed time: 180.56
# Number of point sources considered (52 / 78) in pattern (6 / 9), elapsed time: 180.97
# Number of point sources considered (53 / 78) in pattern (6 / 9), elapsed time: 181.37
# Number of point sources considered (54 / 78) in pattern (6 / 9), elapsed time: 181.77
# Number of point sources considered (55 / 78) in pattern (6 / 9), elapsed time: 182.16
# Number of point sources considered (56 / 78) in pattern (6 / 9), elapsed time: 182.56
# Number of point sources considered (57 / 78) in pattern (6 / 9), elapsed time: 182.96
# Number of point sources considered (58 / 78) in pattern (6 / 9), elapsed time: 183.36
# Number of point sources considered (59 / 78) in pattern (6 / 9), elapsed time: 183.76
# Number of point sources considered (60 / 78) in pattern (6 / 9), elapsed time: 184.16
# Number of point sources considered (61 / 78) in pattern (6 / 9), elapsed time: 184.56
# Number of point sources considered (62 / 78) in pattern (6 / 9), elapsed time: 184.95
# Number of point sources considered (63 / 78) in pattern (6 / 9), elapsed time: 185.35
# Number of point sources considered (64 / 78) in pattern (6 / 9), elapsed time: 185.75
# Number of point sources considered (65 / 78) in pattern (6 / 9), elapsed time: 186.15
# Number of point sources considered (66 / 78) in pattern (6 / 9), elapsed time: 186.58
# Number of point sources considered (67 / 78) in pattern (6 / 9), elapsed time: 186.96
# Number of point sources considered (68 / 78) in pattern (6 / 9), elapsed time: 187.36
# Number of point sources considered (69 / 78) in pattern (6 / 9), elapsed time: 187.76
# Number of point sources considered (70 / 78) in pattern (6 / 9), elapsed time: 188.16
# Number of point sources considered (71 / 78) in pattern (6 / 9), elapsed time: 188.55
# Number of point sources considered (72 / 78) in pattern (6 / 9), elapsed time: 188.94
# Number of point sources considered (73 / 78) in pattern (6 / 9), elapsed time: 189.33
# Number of point sources considered (74 / 78) in pattern (6 / 9), elapsed time: 189.73
# Number of point sources considered (75 / 78) in pattern (6 / 9), elapsed time: 190.13
# Number of point sources considered (76 / 78) in pattern (6 / 9), elapsed time: 190.52
# Number of point sources considered (77 / 78) in pattern (6 / 9), elapsed time: 190.90
# Number of point sources considered (78 / 78) in pattern (6 / 9), elapsed time: 191.29
# Number of point sources considered (1 / 85) in pattern (7 / 9), elapsed time: 191.78
# Number of point sources considered (2 / 85) in pattern (7 / 9), elapsed time: 192.17
# Number of point sources considered (3 / 85) in pattern (7 / 9), elapsed time: 192.55
# Number of point sources considered (4 / 85) in pattern (7 / 9), elapsed time: 192.95
# Number of point sources considered (5 / 85) in pattern (7 / 9), elapsed time: 193.35
# Number of point sources considered (6 / 85) in pattern (7 / 9), elapsed time: 193.73
# Number of point sources considered (7 / 85) in pattern (7 / 9), elapsed time: 194.12
# Number of point sources considered (8 / 85) in pattern (7 / 9), elapsed time: 194.51
# Number of point sources considered (9 / 85) in pattern (7 / 9), elapsed time: 194.90
# Number of point sources considered (10 / 85) in pattern (7 / 9), elapsed time: 195.30
# Number of point sources considered (11 / 85) in pattern (7 / 9), elapsed time: 195.69
# Number of point sources considered (12 / 85) in pattern (7 / 9), elapsed time: 196.09
# Number of point sources considered (13 / 85) in pattern (7 / 9), elapsed time: 196.48
# Number of point sources considered (14 / 85) in pattern (7 / 9), elapsed time: 196.86
# Number of point sources considered (15 / 85) in pattern (7 / 9), elapsed time: 197.24
# Number of point sources considered (16 / 85) in pattern (7 / 9), elapsed time: 197.64
# Number of point sources considered (17 / 85) in pattern (7 / 9), elapsed time: 198.04
# Number of point sources considered (18 / 85) in pattern (7 / 9), elapsed time: 198.43
# Number of point sources considered (19 / 85) in pattern (7 / 9), elapsed time: 198.82
# Number of point sources considered (20 / 85) in pattern (7 / 9), elapsed time: 199.21
# Number of point sources considered (21 / 85) in pattern (7 / 9), elapsed time: 199.61
# Number of point sources considered (22 / 85) in pattern (7 / 9), elapsed time: 200.01
# Number of point sources considered (23 / 85) in pattern (7 / 9), elapsed time: 200.41
# Number of point sources considered (24 / 85) in pattern (7 / 9), elapsed time: 200.80
# Number of point sources considered (25 / 85) in pattern (7 / 9), elapsed time: 201.20
# Number of point sources considered (26 / 85) in pattern (7 / 9), elapsed time: 201.58
# Number of point sources considered (27 / 85) in pattern (7 / 9), elapsed time: 201.96
# Number of point sources considered (28 / 85) in pattern (7 / 9), elapsed time: 202.36
# Number of point sources considered (29 / 85) in pattern (7 / 9), elapsed time: 202.76
# Number of point sources considered (30 / 85) in pattern (7 / 9), elapsed time: 203.15
# Number of point sources considered (31 / 85) in pattern (7 / 9), elapsed time: 203.55
# Number of point sources considered (32 / 85) in pattern (7 / 9), elapsed time: 203.93
# Number of point sources considered (33 / 85) in pattern (7 / 9), elapsed time: 204.33
# Number of point sources considered (34 / 85) in pattern (7 / 9), elapsed time: 204.73
# Number of point sources considered (35 / 85) in pattern (7 / 9), elapsed time: 205.12
# Number of point sources considered (36 / 85) in pattern (7 / 9), elapsed time: 205.52
# Number of point sources considered (37 / 85) in pattern (7 / 9), elapsed time: 205.93
# Number of point sources considered (38 / 85) in pattern (7 / 9), elapsed time: 206.32
# Number of point sources considered (39 / 85) in pattern (7 / 9), elapsed time: 206.71
# Number of point sources considered (40 / 85) in pattern (7 / 9), elapsed time: 207.11
# Number of point sources considered (41 / 85) in pattern (7 / 9), elapsed time: 207.50
# Number of point sources considered (42 / 85) in pattern (7 / 9), elapsed time: 207.89
# Number of point sources considered (43 / 85) in pattern (7 / 9), elapsed time: 208.29
# Number of point sources considered (44 / 85) in pattern (7 / 9), elapsed time: 208.67
# Number of point sources considered (45 / 85) in pattern (7 / 9), elapsed time: 209.05
# Number of point sources considered (46 / 85) in pattern (7 / 9), elapsed time: 209.45
# Number of point sources considered (47 / 85) in pattern (7 / 9), elapsed time: 209.85
# Number of point sources considered (48 / 85) in pattern (7 / 9), elapsed time: 210.25
# Number of point sources considered (49 / 85) in pattern (7 / 9), elapsed time: 210.65
# Number of point sources considered (50 / 85) in pattern (7 / 9), elapsed time: 211.04
# Number of point sources considered (51 / 85) in pattern (7 / 9), elapsed time: 211.43
# Number of point sources considered (52 / 85) in pattern (7 / 9), elapsed time: 211.83
# Number of point sources considered (53 / 85) in pattern (7 / 9), elapsed time: 212.23
# Number of point sources considered (54 / 85) in pattern (7 / 9), elapsed time: 212.63
# Number of point sources considered (55 / 85) in pattern (7 / 9), elapsed time: 213.01
# Number of point sources considered (56 / 85) in pattern (7 / 9), elapsed time: 213.41
# Number of point sources considered (57 / 85) in pattern (7 / 9), elapsed time: 213.79
# Number of point sources considered (58 / 85) in pattern (7 / 9), elapsed time: 214.19
# Number of point sources considered (59 / 85) in pattern (7 / 9), elapsed time: 214.58
# Number of point sources considered (60 / 85) in pattern (7 / 9), elapsed time: 214.97
# Number of point sources considered (61 / 85) in pattern (7 / 9), elapsed time: 215.36
# Number of point sources considered (62 / 85) in pattern (7 / 9), elapsed time: 215.77
# Number of point sources considered (63 / 85) in pattern (7 / 9), elapsed time: 216.16
# Number of point sources considered (64 / 85) in pattern (7 / 9), elapsed time: 216.55
# Number of point sources considered (65 / 85) in pattern (7 / 9), elapsed time: 216.95
# Number of point sources considered (66 / 85) in pattern (7 / 9), elapsed time: 217.34
# Number of point sources considered (67 / 85) in pattern (7 / 9), elapsed time: 217.73
# Number of point sources considered (68 / 85) in pattern (7 / 9), elapsed time: 218.11
# Number of point sources considered (69 / 85) in pattern (7 / 9), elapsed time: 218.49
# Number of point sources considered (70 / 85) in pattern (7 / 9), elapsed time: 218.87
# Number of point sources considered (71 / 85) in pattern (7 / 9), elapsed time: 219.27
# Number of point sources considered (72 / 85) in pattern (7 / 9), elapsed time: 219.66
# Number of point sources considered (73 / 85) in pattern (7 / 9), elapsed time: 220.05
# ...
# Number of point sources considered (56 / 78) in pattern (8 / 9), elapsed time: 246.43
# Number of point sources considered (57 / 78) in pattern (8 / 9), elapsed time: 246.82
# Number of point sources considered (58 / 78) in pattern (8 / 9), elapsed time: 247.20
# Number of point sources considered (59 / 78) in pattern (8 / 9), elapsed time: 247.59
# Number of point sources considered (60 / 78) in pattern (8 / 9), elapsed time: 247.97
# Number of point sources considered (61 / 78) in pattern (8 / 9), elapsed time: 248.35
# Number of point sources considered (62 / 78) in pattern (8 / 9), elapsed time: 248.74
# Number of point sources considered (63 / 78) in pattern (8 / 9), elapsed time: 249.12
# Number of point sources considered (64 / 78) in pattern (8 / 9), elapsed time: 249.50
# Number of point sources considered (65 / 78) in pattern (8 / 9), elapsed time: 249.88
# Number of point sources considered (66 / 78) in pattern (8 / 9), elapsed time: 250.27
# Number of point sources considered (67 / 78) in pattern (8 / 9), elapsed time: 250.65
# Number of point sources considered (68 / 78) in pattern (8 / 9), elapsed time: 251.03
# Number of point sources considered (69 / 78) in pattern (8 / 9), elapsed time: 251.41
# Number of point sources considered (70 / 78) in pattern (8 / 9), elapsed time: 251.79
# Number of point sources considered (71 / 78) in pattern (8 / 9), elapsed time: 252.18
# Number of point sources considered (72 / 78) in pattern (8 / 9), elapsed time: 252.56
# Number of point sources considered (73 / 78) in pattern (8 / 9), elapsed time: 252.95
# Number of point sources considered (74 / 78) in pattern (8 / 9), elapsed time: 253.33
# Number of point sources considered (75 / 78) in pattern (8 / 9), elapsed time: 253.71
# Number of point sources considered (76 / 78) in pattern (8 / 9), elapsed time: 254.09
# Number of point sources considered (77 / 78) in pattern (8 / 9), elapsed time: 254.47
# Number of point sources considered (78 / 78) in pattern (8 / 9), elapsed time: 254.85
# Number of point sources considered (1 / 160) in pattern (9 / 9), elapsed time: 255.33
# Number of point sources considered (2 / 160) in pattern (9 / 9), elapsed time: 255.71
# Number of point sources considered (3 / 160) in pattern (9 / 9), elapsed time: 256.09
# Number of point sources considered (4 / 160) in pattern (9 / 9), elapsed time: 256.48
# Number of point sources considered (5 / 160) in pattern (9 / 9), elapsed time: 256.86
# Number of point sources considered (6 / 160) in pattern (9 / 9), elapsed time: 257.24
# Number of point sources considered (7 / 160) in pattern (9 / 9), elapsed time: 257.64
# Number of point sources considered (8 / 160) in pattern (9 / 9), elapsed time: 258.03
# Number of point sources considered (9 / 160) in pattern (9 / 9), elapsed time: 258.41
# Number of point sources considered (10 / 160) in pattern (9 / 9), elapsed time: 258.80
# Number of point sources considered (11 / 160) in pattern (9 / 9), elapsed time: 259.18
# Number of point sources considered (12 / 160) in pattern (9 / 9), elapsed time: 259.56
# Number of point sources considered (13 / 160) in pattern (9 / 9), elapsed time: 259.94
# Number of point sources considered (14 / 160) in pattern (9 / 9), elapsed time: 260.33
# Number of point sources considered (15 / 160) in pattern (9 / 9), elapsed time: 260.71
# Number of point sources considered (16 / 160) in pattern (9 / 9), elapsed time: 261.09
# Number of point sources considered (17 / 160) in pattern (9 / 9), elapsed time: 261.48
# Number of point sources considered (18 / 160) in pattern (9 / 9), elapsed time: 261.86
# Number of point sources considered (19 / 160) in pattern (9 / 9), elapsed time: 262.25
# Number of point sources considered (20 / 160) in pattern (9 / 9), elapsed time: 262.63
# Number of point sources considered (21 / 160) in pattern (9 / 9), elapsed time: 263.01
# Number of point sources considered (22 / 160) in pattern (9 / 9), elapsed time: 263.39
# Number of point sources considered (23 / 160) in pattern (9 / 9), elapsed time: 263.78
# Number of point sources considered (24 / 160) in pattern (9 / 9), elapsed time: 264.16
# Number of point sources considered (25 / 160) in pattern (9 / 9), elapsed time: 264.55
# Number of point sources considered (26 / 160) in pattern (9 / 9), elapsed time: 264.93
# Number of point sources considered (27 / 160) in pattern (9 / 9), elapsed time: 265.31
# Number of point sources considered (28 / 160) in pattern (9 / 9), elapsed time: 265.70
# Number of point sources considered (29 / 160) in pattern (9 / 9), elapsed time: 266.08
# Number of point sources considered (30 / 160) in pattern (9 / 9), elapsed time: 266.47
# Number of point sources considered (31 / 160) in pattern (9 / 9), elapsed time: 266.85
# Number of point sources considered (32 / 160) in pattern (9 / 9), elapsed time: 267.24
# Number of point sources considered (33 / 160) in pattern (9 / 9), elapsed time: 267.62
# Number of point sources considered (34 / 160) in pattern (9 / 9), elapsed time: 268.01
# Number of point sources considered (35 / 160) in pattern (9 / 9), elapsed time: 268.39
# Number of point sources considered (36 / 160) in pattern (9 / 9), elapsed time: 268.77
# Number of point sources considered (37 / 160) in pattern (9 / 9), elapsed time: 269.15
# Number of point sources considered (38 / 160) in pattern (9 / 9), elapsed time: 269.53
# Number of point sources considered (39 / 160) in pattern (9 / 9), elapsed time: 269.92
# Number of point sources considered (40 / 160) in pattern (9 / 9), elapsed time: 270.30
# Number of point sources considered (41 / 160) in pattern (9 / 9), elapsed time: 270.69
# Number of point sources considered (42 / 160) in pattern (9 / 9), elapsed time: 271.08
# Number of point sources considered (43 / 160) in pattern (9 / 9), elapsed time: 271.46
# Number of point sources considered (44 / 160) in pattern (9 / 9), elapsed time: 271.85
# Number of point sources considered (45 / 160) in pattern (9 / 9), elapsed time: 272.24
# Number of point sources considered (46 / 160) in pattern (9 / 9), elapsed time: 272.63
# Number of point sources considered (47 / 160) in pattern (9 / 9), elapsed time: 273.01
# Number of point sources considered (48 / 160) in pattern (9 / 9), elapsed time: 273.39
# Number of point sources considered (49 / 160) in pattern (9 / 9), elapsed time: 273.77
# Number of point sources considered (50 / 160) in pattern (9 / 9), elapsed time: 274.16
# Number of point sources considered (51 / 160) in pattern (9 / 9), elapsed time: 274.54
# Number of point sources considered (52 / 160) in pattern (9 / 9), elapsed time: 274.92
# Number of point sources considered (53 / 160) in pattern (9 / 9), elapsed time: 275.31
# Number of point sources considered (54 / 160) in pattern (9 / 9), elapsed time: 275.69
# Number of point sources considered (55 / 160) in pattern (9 / 9), elapsed time: 276.09
# Number of point sources considered (56 / 160) in pattern (9 / 9), elapsed time: 276.47
# Number of point sources considered (57 / 160) in pattern (9 / 9), elapsed time: 276.85
# Number of point sources considered (58 / 160) in pattern (9 / 9), elapsed time: 277.24
# Number of point sources considered (59 / 160) in pattern (9 / 9), elapsed time: 277.63
# Number of point sources considered (60 / 160) in pattern (9 / 9), elapsed time: 278.02
# Number of point sources considered (61 / 160) in pattern (9 / 9), elapsed time: 278.40
# Number of point sources considered (62 / 160) in pattern (9 / 9), elapsed time: 278.79
# Number of point sources considered (63 / 160) in pattern (9 / 9), elapsed time: 279.17
# Number of point sources considered (64 / 160) in pattern (9 / 9), elapsed time: 279.56
# Number of point sources considered (65 / 160) in pattern (9 / 9), elapsed time: 279.94
# Number of point sources considered (66 / 160) in pattern (9 / 9), elapsed time: 280.32
# Number of point sources considered (67 / 160) in pattern (9 / 9), elapsed time: 280.71
# Number of point sources considered (68 / 160) in pattern (9 / 9), elapsed time: 281.09
# Number of point sources considered (69 / 160) in pattern (9 / 9), elapsed time: 281.47
# Number of point sources considered (70 / 160) in pattern (9 / 9), elapsed time: 281.85
# Number of point sources considered (71 / 160) in pattern (9 / 9), elapsed time: 282.24
# Number of point sources considered (72 / 160) in pattern (9 / 9), elapsed time: 282.62
# Number of point sources considered (73 / 160) in pattern (9 / 9), elapsed time: 283.01
# Number of point sources considered (74 / 160) in pattern (9 / 9), elapsed time: 283.39
# Number of point sources considered (75 / 160) in pattern (9 / 9), elapsed time: 283.77
# Number of point sources considered (76 / 160) in pattern (9 / 9), elapsed time: 284.15
# Number of point sources considered (77 / 160) in pattern (9 / 9), elapsed time: 284.54
# Number of point sources considered (78 / 160) in pattern (9 / 9), elapsed time: 284.92
# Number of point sources considered (79 / 160) in pattern (9 / 9), elapsed time: 285.31
# Number of point sources considered (80 / 160) in pattern (9 / 9), elapsed time: 285.69
# Number of point sources considered (81 / 160) in pattern (9 / 9), elapsed time: 286.08
# Number of point sources considered (82 / 160) in pattern (9 / 9), elapsed time: 286.46
# Number of point sources considered (83 / 160) in pattern (9 / 9), elapsed time: 286.84
# Number of point sources considered (84 / 160) in pattern (9 / 9), elapsed time: 287.25
# Number of point sources considered (85 / 160) in pattern (9 / 9), elapsed time: 287.63
# Number of point sources considered (86 / 160) in pattern (9 / 9), elapsed time: 288.01
# Number of point sources considered (87 / 160) in pattern (9 / 9), elapsed time: 288.40
# Number of point sources considered (88 / 160) in pattern (9 / 9), elapsed time: 288.78
# Number of point sources considered (89 / 160) in pattern (9 / 9), elapsed time: 289.17
# Number of point sources considered (90 / 160) in pattern (9 / 9), elapsed time: 289.55
# Number of point sources considered (91 / 160) in pattern (9 / 9), elapsed time: 289.94
# Number of point sources considered (92 / 160) in pattern (9 / 9), elapsed time: 290.32
# Number of point sources considered (93 / 160) in pattern (9 / 9), elapsed time: 290.70
# Number of point sources considered (94 / 160) in pattern (9 / 9), elapsed time: 291.08
# Number of point sources considered (95 / 160) in pattern (9 / 9), elapsed time: 291.47
# Number of point sources considered (96 / 160) in pattern (9 / 9), elapsed time: 291.85
# Number of point sources considered (97 / 160) in pattern (9 / 9), elapsed time: 292.23
# Number of point sources considered (98 / 160) in pattern (9 / 9), elapsed time: 292.61
# Number of point sources considered (99 / 160) in pattern (9 / 9), elapsed time: 293.00
# Number of point sources considered (100 / 160) in pattern (9 / 9), elapsed time: 293.38
# Number of point sources considered (101 / 160) in pattern (9 / 9), elapsed time: 293.76
# Number of point sources considered (102 / 160) in pattern (9 / 9), elapsed time: 294.15
# Number of point sources considered (103 / 160) in pattern (9 / 9), elapsed time: 294.53
# Number of point sources considered (104 / 160) in pattern (9 / 9), elapsed time: 294.91
# Number of point sources considered (105 / 160) in pattern (9 / 9), elapsed time: 295.29
# Number of point sources considered (106 / 160) in pattern (9 / 9), elapsed time: 295.68
# Number of point sources considered (107 / 160) in pattern (9 / 9), elapsed time: 296.06
# Number of point sources considered (108 / 160) in pattern (9 / 9), elapsed time: 296.45
# Number of point sources considered (109 / 160) in pattern (9 / 9), elapsed time: 296.83
# Number of point sources considered (110 / 160) in pattern (9 / 9), elapsed time: 297.21
# Number of point sources considered (111 / 160) in pattern (9 / 9), elapsed time: 297.60
# Number of point sources considered (112 / 160) in pattern (9 / 9), elapsed time: 297.98
# Number of point sources considered (113 / 160) in pattern (9 / 9), elapsed time: 298.36
# Number of point sources considered (114 / 160) in pattern (9 / 9), elapsed time: 298.75
# Number of point sources considered (115 / 160) in pattern (9 / 9), elapsed time: 299.13
# Number of point sources considered (116 / 160) in pattern (9 / 9), elapsed time: 299.51
# Number of point sources considered (117 / 160) in pattern (9 / 9), elapsed time: 299.90
# Number of point sources considered (118 / 160) in pattern (9 / 9), elapsed time: 300.29
# Number of point sources considered (119 / 160) in pattern (9 / 9), elapsed time: 300.68
# Number of point sources considered (120 / 160) in pattern (9 / 9), elapsed time: 301.07
# Number of point sources considered (121 / 160) in pattern (9 / 9), elapsed time: 301.45
# Number of point sources considered (122 / 160) in pattern (9 / 9), elapsed time: 301.84
# Number of point sources considered (123 / 160) in pattern (9 / 9), elapsed time: 302.22
# Number of point sources considered (124 / 160) in pattern (9 / 9), elapsed time: 302.60
# Number of point sources considered (125 / 160) in pattern (9 / 9), elapsed time: 302.99
# Number of point sources considered (126 / 160) in pattern (9 / 9), elapsed time: 303.37
# Number of point sources considered (127 / 160) in pattern (9 / 9), elapsed time: 303.76
# Number of point sources considered (128 / 160) in pattern (9 / 9), elapsed time: 304.14
# Number of point sources considered (129 / 160) in pattern (9 / 9), elapsed time: 304.52
# Number of point sources considered (130 / 160) in pattern (9 / 9), elapsed time: 304.91
# Number of point sources considered (131 / 160) in pattern (9 / 9), elapsed time: 305.29
# Number of point sources considered (132 / 160) in pattern (9 / 9), elapsed time: 305.67
# Number of point sources considered (133 / 160) in pattern (9 / 9), elapsed time: 306.06
# Number of point sources considered (134 / 160) in pattern (9 / 9), elapsed time: 306.44
# Number of point sources considered (135 / 160) in pattern (9 / 9), elapsed time: 306.82
# Number of point sources considered (136 / 160) in pattern (9 / 9), elapsed time: 307.21
# Number of point sources considered (137 / 160) in pattern (9 / 9), elapsed time: 307.59
# Number of point sources considered (138 / 160) in pattern (9 / 9), elapsed time: 307.97
# Number of point sources considered (139 / 160) in pattern (9 / 9), elapsed time: 308.36
# Number of point sources considered (140 / 160) in pattern (9 / 9), elapsed time: 308.74
# Number of point sources considered (141 / 160) in pattern (9 / 9), elapsed time: 309.12
# Number of point sources considered (142 / 160) in pattern (9 / 9), elapsed time: 309.51
# Number of point sources considered (143 / 160) in pattern (9 / 9), elapsed time: 309.89
# Number of point sources considered (144 / 160) in pattern (9 / 9), elapsed time: 310.28
# Number of point sources considered (145 / 160) in pattern (9 / 9), elapsed time: 310.66
# Number of point sources considered (146 / 160) in pattern (9 / 9), elapsed time: 311.04
# Number of point sources considered (147 / 160) in pattern (9 / 9), elapsed time: 311.43
# Number of point sources considered (148 / 160) in pattern (9 / 9), elapsed time: 311.81
# Number of point sources considered (149 / 160) in pattern (9 / 9), elapsed time: 312.20
# Number of point sources considered (150 / 160) in pattern (9 / 9), elapsed time: 312.58
# Number of point sources considered (151 / 160) in pattern (9 / 9), elapsed time: 312.96
# Number of point sources considered (152 / 160) in pattern (9 / 9), elapsed time: 313.34
# Number of point sources considered (153 / 160) in pattern (9 / 9), elapsed time: 313.73
# Number of point sources considered (154 / 160) in pattern (9 / 9), elapsed time: 314.11
# Number of point sources considered (155 / 160) in pattern (9 / 9), elapsed time: 314.49
# Number of point sources considered (156 / 160) in pattern (9 / 9), elapsed time: 314.88
# Number of point sources considered (157 / 160) in pattern (9 / 9), elapsed time: 315.26
# Number of point sources considered (158 / 160) in pattern (9 / 9), elapsed time: 315.64
# Number of point sources considered (159 / 160) in pattern (9 / 9), elapsed time: 316.03
# Number of point sources considered (160 / 160) in pattern (9 / 9), elapsed time: 316.41

# %%
# animate through the simulated Stokes parameters (stack_idx_1: z, stack_idx_2: illumination pattern)
wo.parallel_5D_viewer(np.transpose(Stokes_SEAGLE,(4,1,0,2,3)), num_col=4, size=5, origin='lower', \
                      set_title=True, titles=[r'$S_0$', r'$S_1$', r'$S_2$', r'$S_3$'])
# Out:
# interactive(children=(IntSlider(value=0, description='stack_idx_1', max=99), IntSlider(value=0, description='s…
# <function waveorder.visual.parallel_5D_viewer.<locals>.interact_plot(stack_idx_1, stack_idx_2)>

# %%
# animate through the simulated measured intensity (stack_idx_1: z, stack_idx_2: illumination pattern)
wo.parallel_5D_viewer(np.transpose(I_meas_SEAGLE,(4,1,0,2,3)), num_col=5, size=5, origin='lower', \
                      set_title=True, titles=[r'$I_{ext}$',r'$I_{0}$',r'$I_{45}$',r'$I_{90}$', r'$I_{135}$'])
# Out:
# interactive(children=(IntSlider(value=0, description='stack_idx_1', max=99), IntSlider(value=0, description='s…
# <function waveorder.visual.parallel_5D_viewer.<locals>.interact_plot(stack_idx_1, stack_idx_2)>

# %%
## situation with no noise ##
photon_count = 5000
I_meas_noise = I_meas_SEAGLE/np.mean(I_meas_SEAGLE) * photon_count
#############################


# # Add noise to the measurement ##
# photon_count = 50000
# ext_ratio    = 1000
# const_bg     = photon_count/(0.5*(1-np.cos(chi)))/ext_ratio
# I_meas_noise = (np.random.poisson(I_meas_SEAGLE/np.mean(I_meas_SEAGLE) * photon_count + const_bg)).astype('float64')
# #################################

# %%
# animate through the simulated measured intensity (stack_idx_1: z, stack_idx_2: illumination pattern)
wo.parallel_5D_viewer(np.transpose(I_meas_noise,(4,1,0,2,3)), num_col=5, size=5, origin='lower', \
                      set_title=True, titles=[r'$I_{ext}$',r'$I_{0}$',r'$I_{45}$',r'$I_{90}$', r'$I_{135}$'])
# Out:
# interactive(children=(IntSlider(value=0, description='stack_idx_1', max=99), IntSlider(value=0, description='s…
# <function waveorder.visual.parallel_5D_viewer.<locals>.interact_plot(stack_idx_1, stack_idx_2)>

# %% [markdown]
# #### Save simulation

# %%
# Save simulations

if sample_type == '3D':
    output_file = 'uPTI_simulation_data_NA_det_147_NA_illu_140_3D_spoke_discrete_no_1528_ne_1553_no_noise_Born'
elif sample_type == '2D':
    output_file = 'uPTI_simulation_data_NA_det_147_NA_illu_140_2D_spoke_discrete_no_1528_ne_1553_no_noise_Born'
else:
    print('sample_type needs to be 2D or 3D.')

np.savez(output_file, I_meas=I_meas_noise, lambda_illu=lambda_illu, n_media=n_media, NA_obj=NA_obj, NA_illu=NA_illu,\
                      ps=ps, psz=psz, Source_cont=Source_cont, Source_PolState=Source_PolState, \
                      z_defocus=z_defocus, chi=chi)

# %%
import cupy as cp
import gc
gc.collect()
cp.get_default_memory_pool().free_all_blocks()
